# %%
pip install transformers datasets evaluate seqeval jsonlines
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.41.2)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (2.20.0)
# Requirement already satisfied: evaluate in /usr/local/lib/python3.10/dist-packages (0.4.2)
# Requirement already satisfied: seqeval in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: jsonlines in /usr/local/lib/python3.10/dist-packages (4.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.15.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.23.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (16.1.0)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.0.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec[http]<=2024.5.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.5)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.10/dist-packages (from seqeval) (1.2.2)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonlines) (23.2.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.7.4)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval) (3.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)

# %%
import jsonlines
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import copy
import spacy
import re
from tqdm import tqdm
import pickle
import random

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
with open("/content/drive/MyDrive/Speech-NER/train.pkl", 'rb') as file:
    train = pickle.load(file)

with open("/content/drive/MyDrive/Speech-NER/test.pkl", 'rb') as file:
    test = pickle.load(file)

with open("/content/drive/MyDrive/Speech-NER/aug.pkl", 'rb') as file:
    aug = pickle.load(file)

with open("/content/diverse.pkl", 'rb') as file:
    aug1 = pickle.load(file)

# with open("/content/diverse.pkl", 'rb') as file:
#     aug2 = pickle.load(file)

# %%
aug1[0] = aug1[0] + train[0]
aug1[1] = aug1[1] + train[1]

combined = list(zip(aug1[0], aug1[1]))
random.shuffle(combined)

aug1[0], aug1[1] = zip(*combined)
aug1[0] = list(aug1[0])
aug1[1] = list(aug1[1])

# %%
def get_label_distribution(spans):
  labels = {}
  for i in spans:
      for j in i:
          labels[j['label']] = labels.get(j['label'], 0) + 1

  labels = dict(sorted(labels.items(), key=lambda item: item[0]))
  plt.bar(labels.keys(), labels.values())
  plt.xticks(rotation = 90)
  plt.title("Distribution of NER Tags")
  plt.show()

# %%
get_label_distribution(train[1])

# %%
get_label_distribution(test[1])

# %%
get_label_distribution(aug[1])

# %%
label_list = []
for i in test[1]:
  for j in i:
    if j['label'] not in label_list:
      label_list.append(j['label'])

label_list
# Out:
# ['PHONE',
#  'PASSPORT_NUM',
#  'BANK_ACCOUNT',
#  'PERSON',
#  'ORG',
#  'CARDINAL',
#  'EMAIL',
#  'NRIC',
#  'GPE',
#  'CAR_PLATE',
#  'CREDIT_CARD',
#  'DATE',
#  'TIME']

# %%
for i in range(len(aug[1])):
  for j in range(len(aug[1][i])-1, -1, -1):
    if aug[1][i][j]['label'] not in label_list:
      del aug[1][i][j]

# %%
id2label = {
    0: "O",
    1: "BANK_ACCOUNT",
    2: "CAR_PLATE",
    3: "CREDIT_CARD",
    4: "DATE",
    5: "EMAIL",
    6: "NRIC",
    7: "ORG",
    8: "PASSPORT_NUM",
    9: "PERSON",
    10: "PHONE",
    11: "TIME",
    12: "GPE",
    13: "CARDINAL"
}

label2id = {
    "O": 0,
    "BANK_ACCOUNT": 1,
    "CAR_PLATE": 2,
    "CREDIT_CARD": 3,
    "DATE": 4,
    "EMAIL": 5,
    "NRIC": 6,
    "ORG": 7,
    "PASSPORT_NUM": 8,
    "PERSON": 9,
    "PHONE": 10,
    "TIME": 11,
    "GPE": 12,
    "CARDINAL": 13
}

# %%
nlp = spacy.load("en_core_web_sm")

token_X = []
tag_y = []
spans = []
texts = []

for i in range(len(aug1[0])):
    doc = nlp(aug1[0][i])
    temp = []
    for j in doc:
        temp.append(str(j))

    flag = True
    tempy = ["O" for k in range(len(temp))]
    for k in aug1[1][i]:
        to_match = aug1[0][k['start']:k['end']]
        span = doc.char_span(k['start'],k['end'])

        try:
          s = span[0].i
          e = span[-1].i
          tag = k['label']

          for l in range(s, e+1):
              tempy[l] = tag
        except:
          flag = False

    if flag:
      token_X.append(temp)
      tag_y.append(tempy)
      spans.append(aug1[1][i])
      texts.append(aug1[0][i])
    else:
      print("Problem at Index {}".format(i))
# Out:
# /usr/local/lib/python3.10/dist-packages/spacy/util.py:1740: UserWarning: [W111] Jupyter notebook detected: if using `prefer_gpu()` or `require_gpu()`, include it in the same cell right before `spacy.load()` to ensure that the model is loaded on the correct device. More information: http://spacy.io/usage/v3#jupyter-notebook-gpu
#   warnings.warn(Warnings.W111)
# Problem at Index 216
# Problem at Index 317
# Problem at Index 975
# Problem at Index 1000
# Problem at Index 1509
# Problem at Index 2025
# Problem at Index 2071
# Problem at Index 2345
# Problem at Index 2570

# %%
token_y = []
for i in tag_y:
    temp = []
    for j in i:
        temp.append(label2id[j])
    token_y.append(temp)

# %%
def strip(original_string):
    return re.sub(r"\s+", "", original_string)

def count_ws(string, position):
    whitespace_count = 0

    for char in string[:position]:
        if char.isspace():
            whitespace_count += 1

    if position == len(string) or string[position].isspace():
        return position-whitespace_count-1

    return position-whitespace_count

# %%
span_without_space = copy.deepcopy(spans)

for i in range(len(spans)):
    sent = texts[i]
    temp = []
    for j in span_without_space[i]:
        s = j['start']
        e = j['end']
        ns = count_ws(texts[i], s)
        ne = count_ws(texts[i], e)
        j['start'] = ns
        j['end'] = ne

# %%
combined = list(zip(token_X, token_y, span_without_space))
seed_value = 42
random.seed(seed_value)
random.shuffle(combined)
token_X, token_y, span_without_space = zip(*combined)

# %%
data = []
for i in range(len(token_X)):
  temp = {}
  temp['id'] = i
  temp['tokens'] = token_X[i]
  temp['tags'] = token_y[i]
  data.append(temp)

# %%
from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained("distilbert-base-uncased")

# %%
def generate_labels(tokens, spans):
    tokens = tokens[1:-1]
    count = -1
    starts = []
    ends = []
    tags = []
    labels = ["O" for i in range(len(tokens))]

    for i in spans:
        starts.append(i['start'])
        ends.append(i['end'])
        tags.append(i['label'])

    flag = False
    for i in range(len(tokens)):
        for j in tokens[i]:
            if j != "#":
                count = count + 1

            if count in starts:
                flag = True
                start = count
                end = ends[starts.index(start)]
                labels[i] = tags[starts.index(start)]

            elif count in ends:
                labels[i] = tags[ends.index(end)]
                flag = False

            if flag == True:
                labels[i] = tags[starts.index(start)]

    token_y = []
    for i in labels:
        token_y.append(label2id[i])

    return token_y

# %%
import copy

def tokenize_and_align_labels(examples, span):

    tokenized_inputs = tokenizer(examples["tokens"], truncation=True, is_split_into_words=True)
    tokens = tokenizer.convert_ids_to_tokens(tokenized_inputs["input_ids"])
    labels = generate_labels(tokens, span)

    labels.insert(0, -100)
    labels.append(-100)

    tokenized_inputs["labels"] = labels
    return tokenized_inputs

# %%
tokenized_data = [tokenize_and_align_labels(data[i], span_without_space[i]) for i in range(len(data))]

# %%
train, val = train_test_split(tokenized_data, test_size=0.2, random_state=20)

# %%
from transformers import DataCollatorForTokenClassification

data_collator = DataCollatorForTokenClassification(tokenizer=tokenizer, return_tensors="tf")

# %%
import numpy as np

label_list = list(label2id.keys())

def compute_metrics(p):
    predictions, labels = p
    predictions = np.argmax(predictions, axis=2)

    true_predictions = [
        [label_list[p] for (p, l) in zip(prediction, label) if l != -100]
        for prediction, label in zip(predictions, labels)
    ]
    true_labels = [
        [label_list[l] for (p, l) in zip(prediction, label) if l != -100]
        for prediction, label in zip(predictions, labels)
    ]

    total_tokens = sum(len(label) for label in true_labels)
    correct_tokens = sum(1 for pred, label in zip(true_predictions, true_labels) for p, l in zip(pred, label) if p == l)

    accuracy = correct_tokens / total_tokens if total_tokens > 0 else 0

    return {
        "accuracy": accuracy,
    }

# %%
from transformers import create_optimizer
from transformers import TFAutoModelForTokenClassification
from datasets import Dataset
import tensorflow as tf
from transformers.keras_callbacks import KerasMetricCallback
from tensorflow.keras.callbacks import ModelCheckpoint

# Set up training parameters
batch_size = 16
num_train_epochs = 10
num_train_steps = (len(train) // batch_size) * num_train_epochs

# Create optimizer and learning rate schedule
optimizer, lr_schedule = create_optimizer(
    init_lr=2e-5,
    num_train_steps=num_train_steps,
    weight_decay_rate=0.01,
    num_warmup_steps=0,
)

# Load model
model = TFAutoModelForTokenClassification.from_pretrained(
    "distilbert-base-uncased", num_labels=14, id2label=id2label, label2id=label2id
)

# Create datasets
train_dataset = Dataset.from_dict({key: [instance[key] for instance in train] for key in train[0].keys()})
validation_dataset = Dataset.from_dict({key: [instance[key] for instance in val] for key in val[0].keys()})

tf_train_set = model.prepare_tf_dataset(
    train_dataset,
    shuffle=True,
    batch_size=batch_size,
    collate_fn=data_collator,
)

tf_validation_set = model.prepare_tf_dataset(
    validation_dataset,
    shuffle=False,
    batch_size=batch_size,
    collate_fn=data_collator,
)

# Compile model
model.compile(optimizer=optimizer)

# Metric callback
metric_callback = KerasMetricCallback(metric_fn=compute_metrics, eval_dataset=tf_validation_set)

# Model checkpoint callback to save the best model
checkpoint_callback = ModelCheckpoint(
    filepath='content/MyDrive/MyDrive/Speech-NER/Final_Analysis/BERT_Augmented_Diverse.h5',  # Path to save the model file
    monitor='val_loss',        # Metric to monitor
    save_best_only=True,       # Save only the best model
    mode='min',                # Mode to minimize the monitored metric
    verbose=1                  # Verbosity mode
)

# Train model with callbacks
model.fit(
    x=tf_train_set,
    validation_data=tf_validation_set,
    epochs=num_train_epochs,
    callbacks=[metric_callback, checkpoint_callback]
)
# Out:
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFDistilBertForTokenClassification: ['vocab_transform.bias', 'vocab_layer_norm.weight', 'vocab_transform.weight', 'vocab_projector.bias', 'vocab_layer_norm.bias']
# - This IS expected if you are initializing TFDistilBertForTokenClassification from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFDistilBertForTokenClassification from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights or buffers of the TF 2.0 model TFDistilBertForTokenClassification were not initialized from the PyTorch model and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch 1/10
# 214/214 [==============================] - 71s 234ms/step - loss: 0.5324 - val_loss: 0.1666 - accuracy: 0.9606
# Epoch 2/10
# 214/214 [==============================] - 28s 132ms/step - loss: 0.1231 - val_loss: 0.0866 - accuracy: 0.9754
# Epoch 3/10
# 214/214 [==============================] - 28s 132ms/step - loss: 0.0677 - val_loss: 0.0789 - accuracy: 0.9777
# Epoch 4/10
# 214/214 [==============================] - 29s 136ms/step - loss: 0.0473 - val_loss: 0.0797 - accuracy: 0.9771
# Epoch 5/10
# 214/214 [==============================] - 28s 129ms/step - loss: 0.0337 - val_loss: 0.0824 - accuracy: 0.9780
# Epoch 6/10
# 214/214 [==============================] - 29s 134ms/step - loss: 0.0245 - val_loss: 0.0775 - accuracy: 0.9794
# Epoch 7/10
# 214/214 [==============================] - 28s 132ms/step - loss: 0.0196 - val_loss: 0.0786 - accuracy: 0.9800
# Epoch 8/10
# 214/214 [==============================] - 32s 148ms/step - loss: 0.0153 - val_loss: 0.0835 - accuracy: 0.9793
# Epoch 9/10
# 214/214 [==============================] - 28s 132ms/step - loss: 0.0130 - val_loss: 0.0849 - accuracy: 0.9793
# Epoch 10/10
# 214/214 [==============================] - 29s 134ms/step - loss: 0.0119 - val_loss: 0.0849 - accuracy: 0.9794

# %%
model.save_pretrained("/content/MyDrive/MyDrive/Speech-NER/Final_Analysis/BERT_Augmented_Diverse")

# %%
from transformers import TFAutoModelForTokenClassification

# model = TFAutoModelForTokenClassification.from_pretrained("/content/MyDrive/MyDrive/Speech-NER/Final_Analysis/BERT-Augmented")
tokenizer = AutoTokenizer.from_pretrained("distilbert-base-uncased")

# %%
def get_tags(text):
  inputs = tokenizer(text, return_tensors="tf")
  logits = model(**inputs).logits
  predicted_token_class_ids = tf.math.argmax(logits, axis=-1)
  predicted_token_class = [model.config.id2label[t] for t in predicted_token_class_ids[0].numpy().tolist()]
  pred = predicted_token_class[1:-1]
  return pred

# %%
pred = []
tokens = []

for i in test[0]:
  pred.append(get_tags(i))
  tokenized_inputs = tokenizer(i, truncation=True, is_split_into_words=False)
  tokens.append((tokenizer.convert_ids_to_tokens(tokenized_inputs["input_ids"]))[1:-1])

# %%
pred[0]
# Out:
# ['O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'PHONE',
#  'PHONE',
#  'PHONE',
#  'PHONE',
#  'PHONE',
#  'PHONE',
#  'PHONE',
#  'PHONE']

# %%
temp1 = []
for i in range(len(pred)):
  p = pred[i]
  tok = tokens[i]
  count = -1
  temp = []
  for j in range(len(tok)):
    prev_count = 0 + count
    for k in tok[j]:
      if k!= '#':
        count = count + 1
    if p[j] != 'O':
      temp.append([prev_count+1, count, p[j]])
  temp1.append(temp)

# %%
def merge_consecutive_entities(entities):
    merged_entities = []
    current_start = None
    current_end = None
    current_type = None

    for start, end, entity_type in entities:
        if current_type is None:
            current_start = start
            current_end = end
            current_type = entity_type
        elif entity_type == current_type and start == current_end + 1:
            current_end = end
        else:
            merged_entities.append([current_start, current_end, current_type])
            current_start = start
            current_end = end
            current_type = entity_type

    if current_type is not None:
        merged_entities.append([current_start, current_end, current_type])

    return merged_entities

# %%
temp2 = []
for i in temp1:
  temp2.append(merge_consecutive_entities(i))

# %%
final_pred = []
for i in range(len(test[0])):
  nospace = strip(test[0][i])
  temp = []
  for j in temp2[i]:
    count = -1
    ws = 0
    tempp = []
    for k in test[0][i]:
      if k != " ":
        count = count + 1
        if count == j[0]:
          tempp.append(count+ws)
        elif count == j[1]:
          tempp.append(count+ws+1)

      else:
        ws = ws + 1
    tempp.append(j[2])
    temp.append(tempp)
  final_pred.append(temp)

# %%
# Count of Labels for Test Set

labels4 = {}
for i in test[1]:
    for j in i:
        labels4[j['label']] = labels4.get(j['label'], 0) + 1

labels4 = dict(sorted(labels4.items(), key=lambda item: item[0]))
plt.bar(labels4.keys(), labels4.values())
plt.xticks(rotation = 90)
plt.title("Distribution of NER Tags after Removal of Entities")
plt.show()

# %%
true1 = []
for i in test[1]:
  temp = []
  for j in i:
    temp.append([j['start'], j['end'], j['label']])
  true1.append(temp)

# %%
def empty_dict(l):
    di = {}
    for i in l:
        di[i] = 0
    return di

# %%
# Perfect Match
# Partial Match
# Hallucination - Insertion
# Omission - Deletion
# Substitution

perf_match = empty_dict(list(label_list))
part_match = empty_dict(list(label_list))
insert = empty_dict(list(label_list))
delete = empty_dict(list(label_list))
sub = empty_dict(list(label_list))

true = copy.deepcopy(true1)
pred1 = copy.deepcopy(final_pred)

for i in range(len(true)):
    for j in true[i]:
        if j in pred1[i]:
            perf_match[j[2]] = perf_match.get(j[2], 0) + 1
            print(j, "---", pred1[i], " -- Perfect Match")
            pred1[i].remove(j)

        else:
            start = j[0]
            end = j[1]
            tag = j[2]
            flag = False
            for k in pred1[i][::-1]:
                if start == k[0]:
                    flag = True
                    if tag == k[-1]:
                        part_match[j[2]] = part_match.get(j[2], 0) + 1
                        print(j, "---", k, " -- Partial Match")
                        pred1[i].remove(k)

                    elif tag != k[-1]:
                        sub[j[2]] = sub.get(j[2], 0) + 1
                        print(j, "---", k, " -- Substitution")
                        pred1[i].remove(k)

            if flag == False:
                print(j, " -- Omission")
                delete[j[2]] = delete.get(j[2], 0) + 1

    if len(pred1[i]) != 0:
        for k in pred1[i]:
            print( k, " -- Hallucination")
            insert[k[-1]] = insert.get(k[-1], 0) + 1
# Out:
# [34, 73, 'PHONE'] --- [[34, 73, 'PHONE']]  -- Perfect Match
# [99, 110, 'PASSPORT_NUM'] --- [[99, 110, 'PASSPORT_NUM'], [130, 141, 'PASSPORT_NUM']]  -- Perfect Match
# [130, 141, 'PASSPORT_NUM'] --- [[130, 141, 'PASSPORT_NUM']]  -- Perfect Match
# [35, 72, 'PHONE'] --- [[35, 72, 'PHONE']]  -- Perfect Match
# [0, 41, 'PHONE'] --- [[0, 41, 'PHONE']]  -- Perfect Match
# [55, 66, 'BANK_ACCOUNT'] --- [[55, 66, 'BANK_ACCOUNT']]  -- Perfect Match
# [0, 7, 'PERSON'] --- [0, 8, 'PERSON']  -- Partial Match
# [10, 13, 'ORG'] --- [[10, 13, 'ORG'], [30, 40, 'BANK_ACCOUNT'], [40, 49, 'PHONE']]  -- Perfect Match
# [30, 49, 'BANK_ACCOUNT'] --- [30, 40, 'BANK_ACCOUNT']  -- Partial Match
# [40, 49, 'PHONE']  -- Hallucination
# [230, 241, 'BANK_ACCOUNT'] --- [[230, 241, 'BANK_ACCOUNT']]  -- Perfect Match
# [174, 181, 'CARDINAL']  -- Omission
# [0, 26, 'EMAIL'] --- [[0, 26, 'EMAIL'], [30, 33, 'EMAIL']]  -- Perfect Match
# [30, 32, 'ORG'] --- [30, 33, 'EMAIL']  -- Substitution
# [35, 40, 'ORG']  -- Omission
# [0, 9, 'NRIC'] --- [[0, 9, 'NRIC'], [91, 99, 'CARDINAL']]  -- Perfect Match
# [91, 99, 'CARDINAL']  -- Hallucination
# [0, 'PASSPORT_NUM']  -- Hallucination
# [103, 106, 'CARDINAL']  -- Hallucination
# [107, 'PASSPORT_NUM']  -- Hallucination
# [36, 47, 'BANK_ACCOUNT'] --- [[36, 47, 'BANK_ACCOUNT']]  -- Perfect Match
# [39, 60, 'EMAIL'] --- [[39, 60, 'EMAIL'], [84, 93, 'PHONE']]  -- Perfect Match
# [84, 93, 'PHONE'] --- [[84, 93, 'PHONE']]  -- Perfect Match
# [141, 145, 'CARDINAL']  -- Omission
# [157, 161, 'CARDINAL']  -- Omission
# [169, 178, 'GPE'] --- [[169, 178, 'GPE']]  -- Perfect Match
# [114, 125, 'BANK_ACCOUNT'] --- [[114, 125, 'BANK_ACCOUNT']]  -- Perfect Match
# [8, 15, 'ORG']  -- Omission
# [37, 73, 'PHONE'] --- [[37, 73, 'PHONE']]  -- Perfect Match
# [0, 9, 'CAR_PLATE'] --- [[0, 9, 'CAR_PLATE'], [55, 62, 'PERSON'], [93, 101, 'CAR_PLATE']]  -- Perfect Match
# [41, 50, 'GPE']  -- Omission
# [55, 62, 'PERSON'] --- [[55, 62, 'PERSON'], [93, 101, 'CAR_PLATE']]  -- Perfect Match
# [93, 101, 'CAR_PLATE'] --- [[93, 101, 'CAR_PLATE']]  -- Perfect Match
# [21, 49, 'EMAIL'] --- [21, 26, 'PERSON']  -- Substitution
# [27, 49, 'EMAIL']  -- Hallucination
# [22, 49, 'EMAIL'] --- [[22, 49, 'EMAIL']]  -- Perfect Match
# [0, 19, 'CREDIT_CARD'] --- [[0, 19, 'CREDIT_CARD'], [24, 40, 'ORG'], [95, 104, 'PHONE']]  -- Perfect Match
# [24, 40, 'ORG'] --- [[24, 40, 'ORG'], [95, 104, 'PHONE']]  -- Perfect Match
# [50, 54, 'PERSON']  -- Omission
# [95, 104, 'PHONE'] --- [[95, 104, 'PHONE']]  -- Perfect Match
# [65, 75, 'DATE']  -- Omission
# [0, 7, 'PERSON']  -- Omission
# [48, 58, 'PASSPORT_NUM'] --- [[3, 7, 'PERSON'], [48, 58, 'PASSPORT_NUM']]  -- Perfect Match
# [3, 7, 'PERSON']  -- Hallucination
# [10, 13, 'CARDINAL']  -- Hallucination
# [0, 5, 'PERSON'] --- [0, 7, 'PERSON']  -- Partial Match
# [25, 63, 'PHONE'] --- [[25, 63, 'PHONE']]  -- Perfect Match
# [19, 26, 'TIME'] --- [[3, 12, 'TIME'], [19, 26, 'TIME']]  -- Perfect Match
# [3, 12, 'TIME'] --- [[3, 12, 'TIME']]  -- Perfect Match
# [0, 7, 'PERSON'] --- [0, 8, 'PERSON']  -- Partial Match
# [10, 13, 'ORG'] --- [[10, 13, 'ORG'], [30, 43, 'BANK_ACCOUNT']]  -- Perfect Match
# [30, 43, 'BANK_ACCOUNT'] --- [[30, 43, 'BANK_ACCOUNT']]  -- Perfect Match
# [0, 15, 'EMAIL'] --- [[0, 15, 'EMAIL'], [39, 49, 'PHONE']]  -- Perfect Match
# [39, 49, 'PHONE'] --- [[39, 49, 'PHONE']]  -- Perfect Match
# [25, 32, 'DATE'] --- [25, 51, 'DATE']  -- Partial Match
# [33, 51, 'DATE']  -- Omission
# [41, 51, 'PERSON']  -- Omission
# [10, 13, 'PERSON']  -- Hallucination
# [46, 51, 'PERSON']  -- Hallucination
# [0, 10, 'PASSPORT_NUM'] --- [0, 11, 'PASSPORT_NUM']  -- Partial Match
# [40, 48, 'PERSON'] --- [[40, 48, 'PERSON']]  -- Perfect Match
# [35, 46, 'PASSPORT_NUM'] --- [[35, 46, 'PASSPORT_NUM']]  -- Perfect Match
# [4, 9, 'GPE'] --- [[4, 9, 'GPE'], [37, 42, 'GPE']]  -- Perfect Match
# [37, 42, 'GPE'] --- [[37, 42, 'GPE']]  -- Perfect Match
# [33, 79, 'EMAIL'] --- [[33, 79, 'EMAIL']]  -- Perfect Match
# [0, 4, 'ORG'] --- [[0, 4, 'ORG'], [27, 38, 'BANK_ACCOUNT']]  -- Perfect Match
# [27, 38, 'BANK_ACCOUNT'] --- [[27, 38, 'BANK_ACCOUNT']]  -- Perfect Match
# [0, 19, 'BANK_ACCOUNT'] --- [0, 19, 'CREDIT_CARD']  -- Substitution
# [34, 39, 'PERSON'] --- [34, 38, 'PERSON']  -- Partial Match
# [90, 98, 'NRIC'] --- [90, 'NRIC']  -- Partial Match
# [112, 133, 'EMAIL'] --- [[91, 98, 'EMAIL'], [112, 133, 'EMAIL']]  -- Perfect Match
# [91, 98, 'EMAIL']  -- Hallucination
# [0, 5, 'PERSON'] --- [[0, 5, 'PERSON'], [35, 39, 'CAR_PLATE'], [39, 42, 'NRIC'], [82, 86, 'CAR_PLATE'], [86, 90, 'NRIC']]  -- Perfect Match
# [35, 42, 'CAR_PLATE'] --- [35, 39, 'CAR_PLATE']  -- Partial Match
# [82, 90, 'CAR_PLATE'] --- [82, 86, 'CAR_PLATE']  -- Partial Match
# [39, 42, 'NRIC']  -- Hallucination
# [86, 90, 'NRIC']  -- Hallucination
# [21, 28, 'CAR_PLATE'] --- [[8, 13, 'ORG'], [21, 28, 'CAR_PLATE']]  -- Perfect Match
# [5, 13, 'ORG']  -- Omission
# [8, 13, 'ORG']  -- Hallucination
# [99, 130, 'PHONE'] --- [[99, 130, 'PHONE']]  -- Perfect Match
# [21, 30, 'NRIC'] --- [[21, 30, 'NRIC']]  -- Perfect Match
# [0, 8, 'CAR_PLATE'] --- [0, 9, 'CAR_PLATE']  -- Partial Match
# [25, 31, 'PERSON']  -- Omission
# [27, 31, 'PERSON']  -- Hallucination
# [28, 39, 'CARDINAL']  -- Omission
# [53, 56, 'CARDINAL']  -- Omission
# [25, 37, 'CARDINAL']  -- Hallucination
# [16, 55, 'EMAIL'] --- [[0, 5, 'PERSON'], [16, 55, 'EMAIL']]  -- Perfect Match
# [0, 4, 'PERSON'] --- [0, 5, 'PERSON']  -- Partial Match
# [16, 57, 'PHONE']  -- Omission
# [101, 116, 'NRIC'] --- [[101, 116, 'NRIC']]  -- Perfect Match
# [76, 80, 'CARDINAL']  -- Omission
# [1, 34, 'EMAIL'] --- [1, 8, 'PERSON']  -- Substitution
# [8, 20, 'EMAIL']  -- Hallucination
# [24, 34, 'EMAIL']  -- Hallucination
# [77, 87, 'PASSPORT_NUM'] --- [[77, 87, 'PASSPORT_NUM']]  -- Perfect Match
# [43, 53, 'PASSPORT_NUM'] --- [[43, 53, 'PASSPORT_NUM'], [91, 102, 'BANK_ACCOUNT']]  -- Perfect Match
# [91, 102, 'BANK_ACCOUNT'] --- [[91, 102, 'BANK_ACCOUNT']]  -- Perfect Match
# [1, 7, 'PERSON'] --- [1, 8, 'PERSON']  -- Partial Match
# [10, 14, 'ORG'] --- [[10, 14, 'ORG'], [39, 51, 'BANK_ACCOUNT']]  -- Perfect Match
# [39, 51, 'BANK_ACCOUNT'] --- [[39, 51, 'BANK_ACCOUNT']]  -- Perfect Match
# [107, 130, 'EMAIL']  -- Omission
# [41, 44, 'CARDINAL'] --- [[41, 44, 'CARDINAL'], [113, 130, 'EMAIL']]  -- Perfect Match
# [113, 130, 'EMAIL']  -- Hallucination
# [27, 46, 'CREDIT_CARD'] --- [[27, 46, 'CREDIT_CARD'], [66, 85, 'CREDIT_CARD'], [89, 95, 'ORG']]  -- Perfect Match
# [66, 85, 'CREDIT_CARD'] --- [[66, 85, 'CREDIT_CARD'], [89, 95, 'ORG']]  -- Perfect Match
# [89, 95, 'ORG'] --- [[89, 95, 'ORG']]  -- Perfect Match
# [53, 63, 'ORG']  -- Omission
# [72, 75, 'PERSON']  -- Hallucination
# [3, 7, 'PERSON'] --- [[3, 7, 'PERSON'], [17, 22, 'PERSON']]  -- Perfect Match
# [17, 22, 'PERSON'] --- [[17, 22, 'PERSON']]  -- Perfect Match
# [26, 60, 'EMAIL'] --- [[26, 60, 'EMAIL']]  -- Perfect Match
# [239, 246, 'ORG']  -- Omission
# [247, 259, 'ORG']  -- Omission
# [337, 346, 'ORG']  -- Omission
# [241, 'ORG']  -- Hallucination
# [243, 'ORG']  -- Hallucination
# [282, 285, 'CARDINAL']  -- Hallucination
# [50, 61, 'PERSON']  -- Omission
# [76, 87, 'PERSON']  -- Omission
# [57, 61, 'PERSON']  -- Hallucination
# [83, 87, 'PERSON']  -- Hallucination
# [0, 9, 'NRIC'] --- [[0, 9, 'NRIC']]  -- Perfect Match
# [54, 58, 'NRIC']  -- Omission
# [23, 64, 'EMAIL'] --- [[23, 64, 'EMAIL']]  -- Perfect Match
# [21, 55, 'EMAIL'] --- [21, 34, 'PERSON']  -- Substitution
# [35, 55, 'EMAIL']  -- Hallucination
# [30, 46, 'NRIC'] --- [[30, 46, 'NRIC']]  -- Perfect Match
# [0, 4, 'PERSON'] --- [[0, 4, 'PERSON'], [23, 32, 'PHONE']]  -- Perfect Match
# [23, 32, 'PHONE'] --- [[23, 32, 'PHONE']]  -- Perfect Match
# [0, 5, 'PERSON'] --- [0, 6, 'PERSON']  -- Partial Match
# [17, 24, 'CAR_PLATE'] --- [[17, 24, 'CAR_PLATE'], [65, 71, 'CAR_PLATE']]  -- Perfect Match
# [65, 71, 'CAR_PLATE'] --- [[65, 71, 'CAR_PLATE']]  -- Perfect Match
# [0, 5, 'PERSON'] --- [[0, 5, 'PERSON'], [30, 34, 'PERSON'], [35, 39, 'ORG'], [49, 61, 'BANK_ACCOUNT'], [95, 99, 'ORG']]  -- Perfect Match
# [30, 34, 'PERSON'] --- [[30, 34, 'PERSON'], [35, 39, 'ORG'], [49, 61, 'BANK_ACCOUNT'], [95, 99, 'ORG']]  -- Perfect Match
# [35, 39, 'ORG'] --- [[35, 39, 'ORG'], [49, 61, 'BANK_ACCOUNT'], [95, 99, 'ORG']]  -- Perfect Match
# [49, 60, 'BANK_ACCOUNT'] --- [49, 61, 'BANK_ACCOUNT']  -- Partial Match
# [95, 99, 'ORG'] --- [[95, 99, 'ORG']]  -- Perfect Match
# [122, 158, 'EMAIL'] --- [[122, 158, 'EMAIL']]  -- Perfect Match
# [0, 8, 'PERSON'] --- [[0, 8, 'PERSON'], [18, 58, 'PHONE']]  -- Perfect Match
# [18, 58, 'PHONE'] --- [[18, 58, 'PHONE']]  -- Perfect Match
# [0, 4, 'PERSON'] --- [0, 5, 'PERSON']  -- Partial Match
# [18, 56, 'PHONE'] --- [[18, 56, 'PHONE']]  -- Perfect Match
# [14, 26, 'PERSON'] --- [14, 28, 'PERSON']  -- Partial Match
# [46, 58, 'PERSON']  -- Omission
# [43, 54, 'PERSON']  -- Hallucination
# [116, 128, 'BANK_ACCOUNT'] --- [[116, 128, 'BANK_ACCOUNT']]  -- Perfect Match
# [19, 35, 'NRIC'] --- [[0, 4, 'PERSON'], [19, 35, 'NRIC']]  -- Perfect Match
# [0, 4, 'PERSON'] --- [[0, 4, 'PERSON']]  -- Perfect Match
# [57, 73, 'DATE']  -- Omission
# [77, 80, 'CARDINAL'] --- [[63, 73, 'CARDINAL'], [77, 80, 'CARDINAL'], [97, 100, 'CARDINAL'], [105, 111, 'CARDINAL'], [180, 183, 'CARDINAL']]  -- Perfect Match
# [97, 100, 'DATE'] --- [97, 100, 'CARDINAL']  -- Substitution
# [105, 111, 'DATE'] --- [105, 111, 'CARDINAL']  -- Substitution
# [166, 183, 'DATE']  -- Omission
# [63, 73, 'CARDINAL']  -- Hallucination
# [180, 183, 'CARDINAL']  -- Hallucination
# [0, 7, 'PERSON'] --- [[0, 7, 'PERSON'], [12, 17, 'PERSON'], [24, 27, 'PERSON'], [67, 77, 'PASSPORT_NUM'], [90, 99, 'PASSPORT_NUM']]  -- Perfect Match
# [12, 17, 'PERSON'] --- [[12, 17, 'PERSON'], [24, 27, 'PERSON'], [67, 77, 'PASSPORT_NUM'], [90, 99, 'PASSPORT_NUM']]  -- Perfect Match
# [67, 77, 'PASSPORT_NUM'] --- [[24, 27, 'PERSON'], [67, 77, 'PASSPORT_NUM'], [90, 99, 'PASSPORT_NUM']]  -- Perfect Match
# [90, 99, 'PASSPORT_NUM'] --- [[24, 27, 'PERSON'], [90, 99, 'PASSPORT_NUM']]  -- Perfect Match
# [24, 27, 'PERSON']  -- Hallucination
# [80, 90, 'PASSPORT_NUM'] --- [[80, 90, 'PASSPORT_NUM'], [116, 125, 'PASSPORT_NUM']]  -- Perfect Match
# [116, 125, 'PASSPORT_NUM'] --- [[116, 125, 'PASSPORT_NUM']]  -- Perfect Match
# [29, 35, 'DATE']  -- Hallucination
# [40, 46, 'DATE']  -- Hallucination
# [53, 59, 'DATE']  -- Hallucination
# [18, 29, 'NRIC'] --- [18, 28, 'NRIC']  -- Partial Match
# [12, 16, 'ORG']  -- Omission
# [49, 58, 'GPE']  -- Omission
# [59, 68, 'CAR_PLATE']  -- Omission
# [69, 80, 'CAR_PLATE']  -- Omission
# [89, 99, 'CAR_PLATE']  -- Omission
# [63, 68, 'CAR_PLATE']  -- Hallucination
# [73, 80, 'CAR_PLATE']  -- Hallucination
# [92, 99, 'CAR_PLATE']  -- Hallucination
# [17, 44, 'EMAIL'] --- [[17, 44, 'EMAIL']]  -- Perfect Match
# [18, 53, 'EMAIL'] --- [[18, 53, 'EMAIL'], [58, 78, 'EMAIL']]  -- Perfect Match
# [58, 78, 'EMAIL'] --- [[58, 78, 'EMAIL']]  -- Perfect Match
# [17, 56, 'PHONE'] --- [[17, 56, 'PHONE']]  -- Perfect Match
# [12, 18, 'DATE'] --- [[12, 18, 'DATE']]  -- Perfect Match
# [0, 5, 'PERSON'] --- [[0, 5, 'PERSON'], [109, 116, 'CAR_PLATE']]  -- Perfect Match
# [109, 116, 'CAR_PLATE'] --- [[109, 116, 'CAR_PLATE']]  -- Perfect Match
# [0, 4, 'PERSON'] --- [[0, 4, 'PERSON'], [57, 61, 'ORG'], [78, 97, 'CREDIT_CARD']]  -- Perfect Match
# [57, 61, 'ORG'] --- [[57, 61, 'ORG'], [78, 97, 'CREDIT_CARD']]  -- Perfect Match
# [78, 97, 'CREDIT_CARD'] --- [[78, 97, 'CREDIT_CARD']]  -- Perfect Match
# [37, 42, 'GPE'] --- [[13, 16, 'CARDINAL'], [37, 42, 'GPE'], [51, 56, 'CARDINAL']]  -- Perfect Match
# [13, 16, 'CARDINAL']  -- Hallucination
# [51, 56, 'CARDINAL']  -- Hallucination
# [91, 100, 'NRIC'] --- [[91, 100, 'NRIC']]  -- Perfect Match
# [21, 59, 'EMAIL'] --- [[21, 59, 'EMAIL']]  -- Perfect Match
# [1, 39, 'EMAIL'] --- [[1, 39, 'EMAIL']]  -- Perfect Match
# [44, 63, 'CREDIT_CARD'] --- [[44, 63, 'CREDIT_CARD']]  -- Perfect Match
# [26, 29, 'CARDINAL']  -- Hallucination
# [35, 44, 'DATE'] --- [35, 54, 'DATE']  -- Partial Match
# [45, 54, 'DATE']  -- Omission
# [89, 99, 'TIME'] --- [89, 92, 'CARDINAL']  -- Substitution
# [93, 99, 'CARDINAL']  -- Hallucination
# [17, 26, 'CAR_PLATE'] --- [17, 30, 'CAR_PLATE']  -- Partial Match
# [42, 49, 'CAR_PLATE'] --- [[42, 49, 'CAR_PLATE']]  -- Perfect Match
# [34, 73, 'EMAIL'] --- [[34, 73, 'EMAIL']]  -- Perfect Match
# [69, 74, 'CARDINAL']  -- Omission
# [92, 97, 'CARDINAL']  -- Omission
# [106, 111, 'CARDINAL']  -- Omission
# [0, 9, 'NRIC'] --- [[0, 9, 'NRIC'], [54, 69, 'NRIC']]  -- Perfect Match
# [54, 69, 'NRIC'] --- [[54, 69, 'NRIC']]  -- Perfect Match
# [26, 36, 'TIME'] --- [[26, 36, 'TIME']]  -- Perfect Match
# [0, 18, 'EMAIL'] --- [[0, 18, 'EMAIL'], [42, 78, 'PHONE']]  -- Perfect Match
# [42, 78, 'PHONE'] --- [[42, 78, 'PHONE']]  -- Perfect Match
# [43, 46, 'ORG'] --- [[43, 46, 'ORG'], [80, 89, 'PHONE'], [93, 101, 'PHONE']]  -- Perfect Match
# [80, 89, 'PHONE'] --- [[80, 89, 'PHONE'], [93, 101, 'PHONE']]  -- Perfect Match
# [93, 101, 'PHONE'] --- [[93, 101, 'PHONE']]  -- Perfect Match
# [59, 100, 'EMAIL'] --- [[59, 100, 'EMAIL']]  -- Perfect Match
# [47, 63, 'EMAIL'] --- [[47, 63, 'EMAIL'], [87, 96, 'PHONE']]  -- Perfect Match
# [87, 96, 'PHONE'] --- [[87, 96, 'PHONE']]  -- Perfect Match
# [0, 4, 'PERSON'] --- [0, 5, 'PERSON']  -- Partial Match
# [108, 115, 'CAR_PLATE'] --- [[108, 115, 'CAR_PLATE']]  -- Perfect Match
# [37, 46, 'DATE']  -- Omission
# [47, 55, 'DATE']  -- Hallucination
# [56, 66, 'CARDINAL']  -- Hallucination
# [34, 43, 'PHONE'] --- [[34, 43, 'PHONE']]  -- Perfect Match
# [14, 51, 'PHONE']  -- Omission
# [82, 99, 'NRIC']  -- Omission
# [127, 133, 'PERSON'] --- [127, 137, 'PERSON']  -- Partial Match
# [135, 138, 'PERSON']  -- Omission
# [146, 154, 'PERSON']  -- Omission
# [67, 71, 'CARDINAL']  -- Omission
# [98, 'NRIC']  -- Hallucination
# [142, 151, 'PERSON']  -- Hallucination
# [12, 17, 'GPE'] --- [[12, 17, 'GPE'], [60, 65, 'CARDINAL'], [97, 111, 'GPE'], [116, 122, 'GPE']]  -- Perfect Match
# [60, 65, 'CARDINAL'] --- [[60, 65, 'CARDINAL'], [97, 111, 'GPE'], [116, 122, 'GPE']]  -- Perfect Match
# [142, 147, 'CARDINAL']  -- Omission
# [98, 108, 'GPE']  -- Omission
# [120, 125, 'GPE']  -- Omission
# [97, 111, 'GPE']  -- Hallucination
# [116, 122, 'GPE']  -- Hallucination
# [142, 154, 'BANK_ACCOUNT'] --- [142, 155, 'BANK_ACCOUNT']  -- Partial Match
# [4, 8, 'ORG'] --- [[4, 8, 'ORG'], [14, 33, 'CREDIT_CARD']]  -- Perfect Match
# [14, 33, 'CREDIT_CARD'] --- [[14, 33, 'CREDIT_CARD']]  -- Perfect Match
# [49, 60, 'BANK_ACCOUNT'] --- [[49, 60, 'BANK_ACCOUNT']]  -- Perfect Match
# [15, 24, 'DATE']  -- Omission
# [58, 83, 'EMAIL'] --- [[24, 'EMAIL'], [58, 83, 'EMAIL']]  -- Perfect Match
# [26, 29, 'PERSON']  -- Omission
# [24, 'EMAIL']  -- Hallucination
# [46, 51, 'GPE']  -- Omission
# [3, 15, 'PERSON']  -- Omission
# [0, 18, 'PERSON']  -- Hallucination
# [43, 49, 'GPE']  -- Hallucination
# [0, 10, 'PASSPORT_NUM'] --- [[0, 10, 'PASSPORT_NUM']]  -- Perfect Match
# [16, 33, 'NRIC'] --- [[16, 33, 'NRIC']]  -- Perfect Match
# [77, 85, 'GPE']  -- Omission
# [90, 98, 'DATE']  -- Omission
# [76, 77, 'GPE'] --- [76, 84, 'GPE']  -- Partial Match
# [118, 124, 'DATE']  -- Omission
# [84, 96, 'DATE']  -- Hallucination
# [36, 45, 'PASSPORT_NUM'] --- [[36, 45, 'PASSPORT_NUM'], [58, 68, 'PASSPORT_NUM']]  -- Perfect Match
# [58, 68, 'PASSPORT_NUM'] --- [[58, 68, 'PASSPORT_NUM']]  -- Perfect Match
# [5, 8, 'CARDINAL']  -- Omission
# [29, 32, 'CARDINAL'] --- [[29, 32, 'CARDINAL']]  -- Perfect Match
# [81, 93, 'PHONE']  -- Omission
# [85, 93, 'PHONE']  -- Hallucination
# [0, 9, 'PHONE'] --- [[0, 9, 'PHONE']]  -- Perfect Match
# [6, 15, 'PERSON'] --- [[6, 15, 'PERSON'], [32, 39, 'PERSON']]  -- Perfect Match
# [32, 39, 'PERSON'] --- [[32, 39, 'PERSON']]  -- Perfect Match
# [38, 55, 'DATE']  -- Omission
# [67, 75, 'DATE'] --- [[67, 75, 'DATE']]  -- Perfect Match
# [40, 59, 'ORG'] --- [[26, 33, 'PERSON'], [40, 59, 'ORG'], [94, 124, 'EMAIL']]  -- Perfect Match
# [94, 124, 'EMAIL'] --- [[26, 33, 'PERSON'], [94, 124, 'EMAIL']]  -- Perfect Match
# [26, 33, 'PERSON']  -- Hallucination
# [0, 10, 'PASSPORT_NUM'] --- [[0, 10, 'PASSPORT_NUM'], [24, 31, 'PERSON']]  -- Perfect Match
# [24, 31, 'PERSON']  -- Hallucination
# [8, 12, 'ORG'] --- [[8, 12, 'ORG'], [21, 40, 'CREDIT_CARD'], [77, 85, 'PHONE']]  -- Perfect Match
# [21, 40, 'CREDIT_CARD'] --- [[21, 40, 'CREDIT_CARD'], [77, 85, 'PHONE']]  -- Perfect Match
# [77, 85, 'PHONE'] --- [[77, 85, 'PHONE']]  -- Perfect Match
# [94, 97, 'CARDINAL']  -- Hallucination
# [86, 120, 'EMAIL'] --- [[86, 120, 'EMAIL']]  -- Perfect Match
# [68, 75, 'CAR_PLATE'] --- [[68, 75, 'CAR_PLATE']]  -- Perfect Match
# [37, 47, 'NRIC'] --- [[37, 47, 'NRIC'], [88, 98, 'NRIC']]  -- Perfect Match
# [88, 98, 'NRIC'] --- [[88, 98, 'NRIC']]  -- Perfect Match
# [63, 66, 'CARDINAL']  -- Omission
# [0, 18, 'EMAIL'] --- [[0, 18, 'EMAIL']]  -- Perfect Match
# [25, 30, 'ORG']  -- Omission
# [49, 54, 'ORG']  -- Omission
# [44, 53, 'PASSPORT_NUM'] --- [[44, 53, 'PASSPORT_NUM'], [58, 68, 'PASSPORT_NUM']]  -- Perfect Match
# [58, 68, 'PASSPORT_NUM'] --- [[58, 68, 'PASSPORT_NUM']]  -- Perfect Match
# [30, 33, 'CARDINAL']  -- Omission
# [0, 19, 'CREDIT_CARD'] --- [[0, 19, 'CREDIT_CARD'], [58, 62, 'ORG']]  -- Perfect Match
# [20, 24, 'PERSON']  -- Omission
# [58, 62, 'ORG'] --- [[58, 62, 'ORG']]  -- Perfect Match
# [76, 84, 'TIME']  -- Hallucination
# [73, 79, 'GPE'] --- [[73, 79, 'GPE']]  -- Perfect Match
# [26, 34, 'PERSON'] --- [[26, 34, 'PERSON'], [119, 124, 'GPE']]  -- Perfect Match
# [72, 81, 'GPE']  -- Omission
# [119, 124, 'GPE']  -- Hallucination
# [7, 16, 'NRIC'] --- [[7, 16, 'NRIC']]  -- Perfect Match
# [25, 28, 'CARDINAL'] --- [[25, 28, 'CARDINAL'], [40, 48, 'CARDINAL']]  -- Perfect Match
# [40, 43, 'CARDINAL'] --- [40, 48, 'CARDINAL']  -- Partial Match
# [85, 95, 'ORG']  -- Omission
# [35, 39, 'NRIC'] --- [[35, 39, 'NRIC'], [73, 107, 'EMAIL']]  -- Perfect Match
# [73, 107, 'EMAIL'] --- [[73, 107, 'EMAIL']]  -- Perfect Match
# [18, 26, 'CAR_PLATE'] --- [[18, 26, 'CAR_PLATE'], [42, 51, 'CAR_PLATE']]  -- Perfect Match
# [42, 51, 'CAR_PLATE'] --- [[42, 51, 'CAR_PLATE']]  -- Perfect Match
# [6, 9, 'CARDINAL']  -- Hallucination
# [10, 'PASSPORT_NUM']  -- Hallucination
# [8, 13, 'ORG']  -- Omission
# [25, 62, 'PHONE'] --- [[25, 62, 'PHONE']]  -- Perfect Match
# [37, 72, 'EMAIL'] --- [[37, 72, 'EMAIL']]  -- Perfect Match
# [88, 97, 'NRIC'] --- [[88, 97, 'NRIC']]  -- Perfect Match
# [0, 7, 'CAR_PLATE'] --- [[0, 7, 'CAR_PLATE']]  -- Perfect Match
# [8, 15, 'ORG']  -- Omission
# [37, 76, 'PHONE'] --- [[37, 76, 'PHONE']]  -- Perfect Match
# [1, 4, 'PERSON'] --- [[1, 4, 'PERSON'], [72, 82, 'NRIC']]  -- Perfect Match
# [72, 82, 'NRIC'] --- [[72, 82, 'NRIC']]  -- Perfect Match
# [41, 53, 'DATE']  -- Omission
# [17, 25, 'ORG']  -- Hallucination
# [26, 44, 'NRIC']  -- Hallucination
# [0, 5, 'CARDINAL'] --- [[0, 5, 'CARDINAL']]  -- Perfect Match
# [9, 52, 'EMAIL']  -- Omission
# [0, 52, 'EMAIL']  -- Hallucination
# [1, 33, 'EMAIL'] --- [[1, 33, 'EMAIL']]  -- Perfect Match
# [50, 53, 'CARDINAL'] --- [[50, 53, 'CARDINAL']]  -- Perfect Match
# [241, 253, 'NRIC']  -- Omission
# [222, 226, 'CARDINAL']  -- Hallucination
# [249, 253, 'NRIC']  -- Hallucination
# [24, 43, 'CREDIT_CARD'] --- [[24, 43, 'CREDIT_CARD']]  -- Perfect Match
# [115, 119, 'PERSON'] --- [[115, 119, 'PERSON'], [158, 177, 'CREDIT_CARD']]  -- Perfect Match
# [158, 177, 'CREDIT_CARD'] --- [[158, 177, 'CREDIT_CARD']]  -- Perfect Match
# [0, 32, 'EMAIL'] --- [[0, 32, 'EMAIL'], [56, 65, 'PHONE']]  -- Perfect Match
# [56, 65, 'PHONE'] --- [[56, 65, 'PHONE']]  -- Perfect Match
# [35, 82, 'EMAIL'] --- [[35, 82, 'EMAIL'], [145, 153, 'PERSON']]  -- Perfect Match
# [145, 149, 'PERSON'] --- [145, 153, 'PERSON']  -- Partial Match
# [151, 154, 'PERSON']  -- Omission
# [32, 38, 'PERSON'] --- [[32, 38, 'PERSON'], [102, 121, 'CREDIT_CARD']]  -- Perfect Match
# [102, 121, 'CREDIT_CARD'] --- [[102, 121, 'CREDIT_CARD']]  -- Perfect Match
# [19, 24, 'CARDINAL'] --- [[19, 24, 'CARDINAL'], [115, 124, 'ORG']]  -- Perfect Match
# [170, 175, 'CARDINAL']  -- Omission
# [115, 124, 'ORG']  -- Hallucination
# [17, 48, 'EMAIL']  -- Omission
# [13, 48, 'EMAIL']  -- Hallucination
# [39, 79, 'PHONE'] --- [[39, 79, 'PHONE']]  -- Perfect Match
# [0, 10, 'NRIC'] --- [[0, 10, 'NRIC']]  -- Perfect Match
# [79, 106, 'EMAIL'] --- [[45, 49, 'CARDINAL'], [79, 106, 'EMAIL']]  -- Perfect Match
# [45, 49, 'CARDINAL'] --- [[45, 49, 'CARDINAL']]  -- Perfect Match
# [1, 5, 'PERSON']  -- Omission
# [43, 52, 'PASSPORT_NUM'] --- [[43, 52, 'PASSPORT_NUM'], [57, 67, 'PASSPORT_NUM']]  -- Perfect Match
# [57, 67, 'PASSPORT_NUM'] --- [[57, 67, 'PASSPORT_NUM']]  -- Perfect Match
# [80, 92, 'BANK_ACCOUNT'] --- [[80, 92, 'BANK_ACCOUNT']]  -- Perfect Match
# [52, 90, 'PHONE'] --- [[52, 90, 'PHONE']]  -- Perfect Match

# %%
perfect = []
part = []
substituted = []
hallucinated = []
omitted = []

for i in list(label_list):
    try:
        num = labels4[i]
        perfect.append((perf_match[i]/num)*100)
        part.append((part_match[i]/num)*100)
        substituted.append((sub[i]/num)*100)
        hallucinated.append(insert[i])
        omitted.append((delete[i]/num)*100)

    except:
        perfect.append(0)
        part.append(0)
        substituted.append(0)
        hallucinated.append(0)
        omitted.append(0)

lists = [perfect, part, substituted, hallucinated, omitted]
list_names = ["Perfect Match Percentage", "Partial Match Percentage", "Percentage of times the Tag was Misclassified as some other Tag", "Number of times, the Tag was wrongly Inserted", "Percentage of times the Tag was not Detected"]

for i, data in enumerate(lists):
    plt.figure(figsize=(10, 6))
    plt.bar(label_list, data, color='maroon')
    plt.xlabel('Labels')
    plt.ylabel('Percentage')
    plt.title(list_names[i])
    plt.xticks(rotation=90)
    plt.tight_layout()
    plt.show()

# %%
import pandas as pd

data = {
    'Tag': list(label_list),
    'Perfect (%)': perfect,
    'Part (%)': part,
    'Substituted (%)': substituted,
    'Hallucinated': hallucinated,
    'Omitted (%)': omitted
}

df = pd.DataFrame(data)
df
# Out:
#              Tag  Perfect (%)   Part (%)  Substituted (%)  Hallucinated  \
# 0              O     0.000000   0.000000         0.000000             0
# 1   BANK_ACCOUNT    73.333333  20.000000         6.666667             0
# 2      CAR_PLATE    63.157895  21.052632         0.000000             3
# 3    CREDIT_CARD   100.000000   0.000000         0.000000             0
# 4           DATE    11.764706  11.764706        11.764706             5
# 5          EMAIL    82.857143   0.000000         8.571429             9
# 6           NRIC    77.272727   9.090909         0.000000             5
# 7            ORG    50.000000   0.000000         3.571429             5
# 8   PASSPORT_NUM    94.736842   5.263158         0.000000             3
# 9         PERSON    43.478261  26.086957         0.000000            13
# 10         PHONE    89.285714   0.000000         0.000000             2
# 11          TIME    75.000000   0.000000        25.000000             1
# 12           GPE    42.857143   7.142857         0.000000             4
# 13      CARDINAL    36.000000   4.000000         0.000000            15
#
#     Omitted (%)
# 0      0.000000
# 1      0.000000
# 2     15.789474
# 3      0.000000
# 4     64.705882
# 5      8.571429
# 6     13.636364
# 7     46.428571
# 8      0.000000
# 9     30.434783
# 10    10.714286
# 11     0.000000
# 12    50.000000
# 13    60.000000

# %%
import pandas as pd

data = {
    'Tag': ['BANK_ACCOUNT', 'CAR_PLATE', 'CREDIT_CARD', 'DATE', 'EMAIL', 'NRIC', 
            'ORG', 'PASSPORT_NUM', 'PERSON', 'PHONE', 'TIME', 'GPE', 'CARDINAL'],
    'Perfect (%)': [73.333333, 63.157895, 100.000000, 11.764706, 82.857143, 
                    77.272727, 50.000000, 94.736842, 43.478261, 89.285714, 75.000000, 
                    42.857143, 36.000000],
    'Part (%)': [ 20.000000, 21.052632, 0.000000, 11.764706, 0.000000, 
                 9.090909, 0.000000, 5.263158, 26.086957, 0.000000, 0.000000, 
                 7.142857, 4.000000],
    'Substituted (%)': [ 6.666667, 0.000000, 0.000000, 11.764706, 8.571429, 
                        0.000000, 3.571429, 0.000000, 0.000000, 0.000000, 25.000000, 
                        0.000000, 0.000000],
    'Hallucinated': [ 0, 3, 0, 5, 9, 5, 5, 3, 13, 2, 1, 4, 15],
    'Omitted (%)': [0.000000, 15.789474, 0.000000, 64.705882, 8.571429, 
                    13.636364, 46.428571, 0.000000, 30.434783, 10.714286, 0.000000, 
                    50.000000, 60.000000]
}

df = pd.DataFrame(data)

avg_row = df.iloc[:].mean()
avg_row['Tag'] = 'Average'

df = df.append(avg_row, ignore_index=True)

df
# Out:
# /var/folders/yl/5879yj014q11kbqcnjh_rd0m0000gn/T/ipykernel_3908/69507303.py:23: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   avg_row = df.iloc[:].mean()
# /var/folders/yl/5879yj014q11kbqcnjh_rd0m0000gn/T/ipykernel_3908/69507303.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(avg_row, ignore_index=True)
#              Tag  Perfect (%)   Part (%)  Substituted (%)  Hallucinated  \
# 0   BANK_ACCOUNT    73.333333  20.000000         6.666667           0.0
# 1      CAR_PLATE    63.157895  21.052632         0.000000           3.0
# 2    CREDIT_CARD   100.000000   0.000000         0.000000           0.0
# 3           DATE    11.764706  11.764706        11.764706           5.0
# 4          EMAIL    82.857143   0.000000         8.571429           9.0
# 5           NRIC    77.272727   9.090909         0.000000           5.0
# 6            ORG    50.000000   0.000000         3.571429           5.0
# 7   PASSPORT_NUM    94.736842   5.263158         0.000000           3.0
# 8         PERSON    43.478261  26.086957         0.000000          13.0
# 9          PHONE    89.285714   0.000000         0.000000           2.0
# 10          TIME    75.000000   0.000000        25.000000           1.0
# 11           GPE    42.857143   7.142857         0.000000           4.0
# 12      CARDINAL    36.000000   4.000000         0.000000          15.0
# 13       Average    64.595674   8.030863         4.274941           5.0
#
#     Omitted (%)
# 0      0.000000
# 1     15.789474
# 2      0.000000
# 3     64.705882
# 4      8.571429
# 5     13.636364
# 6     46.428571
# 7      0.000000
# 8     30.434783
# 9     10.714286
# 10     0.000000
# 11    50.000000
# 12    60.000000
# 13    23.098522
