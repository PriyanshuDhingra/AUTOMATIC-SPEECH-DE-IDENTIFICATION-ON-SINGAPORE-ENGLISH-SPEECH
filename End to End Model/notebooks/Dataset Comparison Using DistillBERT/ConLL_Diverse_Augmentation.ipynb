# %%
pip install transformers datasets evaluate seqeval jsonlines
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.41.2)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (2.20.0)
# Requirement already satisfied: evaluate in /usr/local/lib/python3.10/dist-packages (0.4.2)
# Requirement already satisfied: seqeval in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: jsonlines in /usr/local/lib/python3.10/dist-packages (4.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.15.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.23.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (16.1.0)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.0.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec[http]<=2024.5.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.5)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.10/dist-packages (from seqeval) (1.2.2)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonlines) (23.2.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.7.4)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval) (3.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)

# %%
import jsonlines
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import copy
import spacy
import re
from tqdm import tqdm
import pickle
import random

# %%
id2label = {
    0: "O",
    1: "PERSON",
    2: "PERSON",
    3: "ORG",
    4: "ORG",
    5: "LOC",
    6: "LOC",
    7: "MISC",
    8: "MISC"
}

def normalise_data(spans):
  prev_label = -1
  prev_end = -1
  prev_start = -1
  count = 0
  for i in range(len(spans)):
    if prev_label == -1:
      prev_label = spans[i]['label']
      prev_end = spans[i]['end']
      prev_start = spans[i]['start']

    else:
      if prev_label == spans[i]['label'] and prev_end == spans[i]['start'] - 1:
        spans[i]['start'] = prev_start
        del spans[i-1]
        return spans

      else:
        prev_label = spans[i]['label']
        prev_end = spans[i]['end']
        prev_start = spans[i]['start']

  return 1

def conll_to_format(conll_data):
  split_text = conll_data['tokens']
  split_tags = conll_data['ner_tags']

  format_text = []
  format_tags = []

  for i in range(len(split_text)):
    format_text.append(" ".join(split_text[i]))

  for i in range(len(split_tags)):
    format_tags.append([id2label[tag] for tag in split_tags[i]])

  spans = []
  for i in range(len(format_tags)):
    temp = []
    for j in range(len(format_tags[i])):
      if format_tags[i][j] != "O":
        start = format_text[i].find(split_text[i][j])
        end = start + len(split_text[i][j])
        temp.append({"start": start, "end": end, "label": format_tags[i][j]})
    spans.append(temp)

  new_spans = []
  for i in range(len(spans)):
    while(normalise_data(spans[i]) != 1):
      normalise_data(spans[i])

    new_spans.append(spans[i])

  return format_text, new_spans

# %%
from datasets import load_dataset
dataset = load_dataset('/content/conll2003.py', 'conll2003')

# %%
val = conll_to_format(dataset['validation'])
train = conll_to_format(dataset['train'])

# %%
with open("/content/conll_train.pkl", 'rb') as file:
    base_train = pickle.load(file)
with open("/content/conll_test.pkl", 'rb') as file:
    test = pickle.load(file)
with open("/content/conll_diverse-2.pkl", 'rb') as file:
    aug1 = pickle.load(file)

# %%
texts = []
spans = []
for i, j in zip(train[0], train[1]):
  if j == []:
    texts.append(i)
    spans.append(j)

base_train[0] = base_train[0] + texts[:1500]
base_train[1] = base_train[1] + spans[:1500]

combined = list(zip(base_train[0], base_train[1]))
random.shuffle(combined)

base_train[0], base_train[1] = zip(*combined)
base_train[0] = list(base_train[0])
base_train[1] = list(base_train[1])

# %%
aug1[0] = aug1[0] + base_train[0]
aug1[1] = aug1[1] + base_train[1]

combined = list(zip(aug1[0], aug1[1]))
random.shuffle(combined)

aug1[0], aug1[1] = zip(*combined)
aug1[0] = list(aug1[0])
aug1[1] = list(aug1[1])

# %%
def get_label_distribution(spans):
  labels = {}
  for i in spans:
      for j in i:
          labels[j['label']] = labels.get(j['label'], 0) + 1

  labels = dict(sorted(labels.items(), key=lambda item: item[0]))
  plt.bar(labels.keys(), labels.values())
  plt.xticks(rotation = 90)
  plt.title("Distribution of NER Tags")
  plt.show()

# %%
get_label_distribution(train[1])

# %%
get_label_distribution(test[1])

# %%
get_label_distribution(aug1[1])

# %%
label_list = []
for i in test[1]:
  for j in i:
    if j['label'] not in label_list:
      label_list.append(j['label'])

label_list
# Out:
# ['LOC', 'PERSON', 'MISC', 'ORG']

# %%
id2label = {
    0: "O",
    1: "PERSON",
    2: "LOC",
    3: "MISC",
    4: "ORG"
}

label2id = {
    "O": 0,
    "PERSON": 1,
    "LOC": 2,
    "MISC": 3,
    "ORG": 4
}

# %%
nlp = spacy.load("en_core_web_sm")

token_X = []
tag_y = []
spans = []
texts = []

for i in range(len(aug1[0])):
    doc = nlp(aug1[0][i])
    temp = []
    for j in doc:
        temp.append(str(j))

    flag = True
    tempy = ["O" for k in range(len(temp))]
    for k in aug1[1][i]:
        to_match = aug1[0][k['start']:k['end']]
        span = doc.char_span(k['start'],k['end'])

        try:
          s = span[0].i
          e = span[-1].i
          tag = k['label']

          for l in range(s, e+1):
              tempy[l] = tag
        except:
          flag = False

    if flag:
      token_X.append(temp)
      tag_y.append(tempy)
      spans.append(aug1[1][i])
      texts.append(aug1[0][i])
    else:
      print("Problem at Index {}".format(i))
# Out:
# /usr/local/lib/python3.10/dist-packages/spacy/util.py:1740: UserWarning: [W111] Jupyter notebook detected: if using `prefer_gpu()` or `require_gpu()`, include it in the same cell right before `spacy.load()` to ensure that the model is loaded on the correct device. More information: http://spacy.io/usage/v3#jupyter-notebook-gpu
#   warnings.warn(Warnings.W111)
# Problem at Index 1185
# Problem at Index 1780
# Problem at Index 1816
# Problem at Index 2685
# Problem at Index 3277
# Problem at Index 5300
# Problem at Index 7327
# Problem at Index 7948
# Problem at Index 9916
# Problem at Index 10294

# %%
token_y = []
for i in tag_y:
    temp = []
    for j in i:
        temp.append(label2id[j])
    token_y.append(temp)

# %%
def strip(original_string):
    return re.sub(r"\s+", "", original_string)

def count_ws(string, position):
    whitespace_count = 0

    for char in string[:position]:
        if char.isspace():
            whitespace_count += 1

    if position == len(string) or string[position].isspace():
        return position-whitespace_count-1

    return position-whitespace_count

# %%
span_without_space = copy.deepcopy(spans)

for i in range(len(spans)):
    sent = texts[i]
    temp = []
    for j in span_without_space[i]:
        s = j['start']
        e = j['end']
        ns = count_ws(texts[i], s)
        ne = count_ws(texts[i], e)
        j['start'] = ns
        j['end'] = ne

# %%
combined = list(zip(token_X, token_y, span_without_space))
seed_value = 42
random.seed(seed_value)
random.shuffle(combined)
token_X, token_y, span_without_space = zip(*combined)

# %%
data = []
for i in range(len(token_X)):
  temp = {}
  temp['id'] = i
  temp['tokens'] = token_X[i]
  temp['tags'] = token_y[i]
  data.append(temp)

# %%
from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained("distilbert-base-uncased")

# %%
def generate_labels(tokens, spans):
    tokens = tokens[1:-1]
    count = -1
    starts = []
    ends = []
    tags = []
    labels = ["O" for i in range(len(tokens))]

    for i in spans:
        starts.append(i['start'])
        ends.append(i['end'])
        tags.append(i['label'])

    flag = False
    for i in range(len(tokens)):
        for j in tokens[i]:
            if j != "#":
                count = count + 1

            if count in starts:
                flag = True
                start = count
                end = ends[starts.index(start)]
                labels[i] = tags[starts.index(start)]

            elif count in ends:
                labels[i] = tags[ends.index(end)]
                flag = False

            if flag == True:
                labels[i] = tags[starts.index(start)]

    token_y = []
    for i in labels:
        token_y.append(label2id[i])

    return token_y

# %%
import copy

def tokenize_and_align_labels(examples, span):

    tokenized_inputs = tokenizer(examples["tokens"], truncation=True, is_split_into_words=True)
    tokens = tokenizer.convert_ids_to_tokens(tokenized_inputs["input_ids"])
    labels = generate_labels(tokens, span)

    labels.insert(0, -100)
    labels.append(-100)

    tokenized_inputs["labels"] = labels
    return tokenized_inputs

# %%
tokenized_data = [tokenize_and_align_labels(data[i], span_without_space[i]) for i in range(len(data))]

# %%
train, val = train_test_split(tokenized_data, test_size=0.2, random_state=20)

# %%
from transformers import DataCollatorForTokenClassification

data_collator = DataCollatorForTokenClassification(tokenizer=tokenizer, return_tensors="tf")

# %%
import numpy as np

label_list = list(label2id.keys())

def compute_metrics(p):
    predictions, labels = p
    predictions = np.argmax(predictions, axis=2)

    true_predictions = [
        [label_list[p] for (p, l) in zip(prediction, label) if l != -100]
        for prediction, label in zip(predictions, labels)
    ]
    true_labels = [
        [label_list[l] for (p, l) in zip(prediction, label) if l != -100]
        for prediction, label in zip(predictions, labels)
    ]

    total_tokens = sum(len(label) for label in true_labels)
    correct_tokens = sum(1 for pred, label in zip(true_predictions, true_labels) for p, l in zip(pred, label) if p == l)

    accuracy = correct_tokens / total_tokens if total_tokens > 0 else 0

    return {
        "accuracy": accuracy,
    }

# %%
from transformers import create_optimizer
from transformers import TFAutoModelForTokenClassification
from datasets import Dataset
import tensorflow as tf
from transformers.keras_callbacks import KerasMetricCallback

# Set up training parameters
batch_size = 16
num_train_epochs = 10
num_train_steps = (len(aug1[0]) // batch_size) * num_train_epochs

# Create optimizer and learning rate schedule
optimizer, lr_schedule = create_optimizer(
    init_lr=2e-5,
    num_train_steps=num_train_steps,
    weight_decay_rate=0.01,
    num_warmup_steps=0,
)

# Load model
model = TFAutoModelForTokenClassification.from_pretrained(
    "distilbert-base-uncased", num_labels=5, id2label=id2label, label2id=label2id
)

# Create datasets
train_dataset = Dataset.from_dict({key: [instance[key] for instance in train] for key in train[0].keys()})
validation_dataset = Dataset.from_dict({key: [instance[key] for instance in val] for key in val[0].keys()})

tf_train_set = model.prepare_tf_dataset(
    train_dataset,
    shuffle=True,
    batch_size=batch_size,
    collate_fn=data_collator,
)

tf_validation_set = model.prepare_tf_dataset(
    validation_dataset,
    shuffle=False,
    batch_size=batch_size,
    collate_fn=data_collator,
)

# Compile model
model.compile(optimizer=optimizer)

metric_callback = KerasMetricCallback(metric_fn=compute_metrics, eval_dataset=tf_validation_set)

# Train model with callbacks
model.fit(x=tf_train_set, validation_data=tf_validation_set, epochs=num_train_epochs, callbacks=metric_callback)
# Out:
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFDistilBertForTokenClassification: ['vocab_projector.bias', 'vocab_transform.bias', 'vocab_layer_norm.bias', 'vocab_transform.weight', 'vocab_layer_norm.weight']
# - This IS expected if you are initializing TFDistilBertForTokenClassification from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFDistilBertForTokenClassification from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights or buffers of the TF 2.0 model TFDistilBertForTokenClassification were not initialized from the PyTorch model and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch 1/10
# 522/522 [==============================] - 93s 136ms/step - loss: 0.2525 - val_loss: 0.1582 - accuracy: 0.9413
# Epoch 2/10
# 522/522 [==============================] - 54s 104ms/step - loss: 0.1188 - val_loss: 0.1358 - accuracy: 0.9500
# Epoch 3/10
# 522/522 [==============================] - 56s 107ms/step - loss: 0.0732 - val_loss: 0.1342 - accuracy: 0.9534
# Epoch 4/10
# 522/522 [==============================] - 57s 109ms/step - loss: 0.0463 - val_loss: 0.1533 - accuracy: 0.9538
# Epoch 5/10
# 522/522 [==============================] - 57s 109ms/step - loss: 0.0284 - val_loss: 0.1655 - accuracy: 0.9544
# Epoch 6/10
# 522/522 [==============================] - 55s 106ms/step - loss: 0.0200 - val_loss: 0.1717 - accuracy: 0.9559
# Epoch 7/10
# 522/522 [==============================] - 57s 109ms/step - loss: 0.0132 - val_loss: 0.1909 - accuracy: 0.9564
# Epoch 8/10
# 522/522 [==============================] - 57s 109ms/step - loss: 0.0099 - val_loss: 0.1979 - accuracy: 0.9561
# Epoch 9/10
# 522/522 [==============================] - 56s 108ms/step - loss: 0.0072 - val_loss: 0.2108 - accuracy: 0.9563
# Epoch 10/10
# 522/522 [==============================] - 55s 105ms/step - loss: 0.0062 - val_loss: 0.2103 - accuracy: 0.9566

# %%
model.save_pretrained("/content/MyDrive/MyDrive/Speech-NER/Final_Analysis/CoNLL_Diverse")

# %%
from transformers import TFAutoModelForTokenClassification

# model = TFAutoModelForTokenClassification.from_pretrained("/content/MyDrive/MyDrive/Speech-NER/Final_Analysis/BERT-Augmented")
tokenizer = AutoTokenizer.from_pretrained("distilbert-base-uncased")

# %%
def get_tags(text):
  inputs = tokenizer(text, return_tensors="tf")
  logits = model(**inputs).logits
  predicted_token_class_ids = tf.math.argmax(logits, axis=-1)
  predicted_token_class = [model.config.id2label[t] for t in predicted_token_class_ids[0].numpy().tolist()]
  pred = predicted_token_class[1:-1]
  return pred

# %%
pred = []
tokens = []

for i in tqdm(test[0]):
  pred.append(get_tags(i))
  tokenized_inputs = tokenizer(i, truncation=True, is_split_into_words=False)
  tokens.append((tokenizer.convert_ids_to_tokens(tokenized_inputs["input_ids"]))[1:-1])
# Out:
# 100%|██████████| 500/500 [00:57<00:00,  8.76it/s]

# %%
pred[0]
# Out:
# ['O', 'O', 'LOC', 'O', 'O', 'O', 'O', 'LOC', 'O', 'O', 'O', 'O']

# %%
temp1 = []
for i in range(len(pred)):
  p = pred[i]
  tok = tokens[i]
  count = -1
  temp = []
  for j in range(len(tok)):
    prev_count = 0 + count
    for k in tok[j]:
      if k!= '#':
        count = count + 1
    if p[j] != 'O':
      temp.append([prev_count+1, count, p[j]])
  temp1.append(temp)

# %%
def merge_consecutive_entities(entities):
    merged_entities = []
    current_start = None
    current_end = None
    current_type = None

    for start, end, entity_type in entities:
        if current_type is None:
            current_start = start
            current_end = end
            current_type = entity_type
        elif entity_type == current_type and start == current_end + 1:
            current_end = end
        else:
            merged_entities.append([current_start, current_end, current_type])
            current_start = start
            current_end = end
            current_type = entity_type

    if current_type is not None:
        merged_entities.append([current_start, current_end, current_type])

    return merged_entities

# %%
temp2 = []
for i in temp1:
  temp2.append(merge_consecutive_entities(i))

# %%
final_pred = []
for i in range(len(test[0])):
  nospace = strip(test[0][i])
  temp = []
  for j in temp2[i]:
    count = -1
    ws = 0
    tempp = []
    for k in test[0][i]:
      if k != " ":
        count = count + 1
        if count == j[0]:
          tempp.append(count+ws)
        elif count == j[1]:
          tempp.append(count+ws+1)

      else:
        ws = ws + 1
    tempp.append(j[2])
    temp.append(tempp)
  final_pred.append(temp)

# %%
# Count of Labels for Test Set

labels4 = {}
for i in test[1]:
    for j in i:
        labels4[j['label']] = labels4.get(j['label'], 0) + 1

labels4 = dict(sorted(labels4.items(), key=lambda item: item[0]))
plt.bar(labels4.keys(), labels4.values())
plt.xticks(rotation = 90)
plt.title("Distribution of NER Tags after Removal of Entities")
plt.show()

# %%
true1 = []
for i in test[1]:
  temp = []
  for j in i:
    temp.append([j['start'], j['end'], j['label']])
  true1.append(temp)

# %%
def empty_dict(l):
    di = {}
    for i in l:
        di[i] = 0
    return di

# %%
# Perfect Match
# Partial Match
# Hallucination - Insertion
# Omission - Deletion
# Substitution

perf_match = empty_dict(list(label_list))
part_match = empty_dict(list(label_list))
insert = empty_dict(list(label_list))
delete = empty_dict(list(label_list))
sub = empty_dict(list(label_list))

true = copy.deepcopy(true1)
pred1 = copy.deepcopy(final_pred)

for i in range(len(true)):
    for j in true[i]:
        if j in pred1[i]:
            perf_match[j[2]] = perf_match.get(j[2], 0) + 1
            print(j, "---", pred1[i], " -- Perfect Match")
            pred1[i].remove(j)

        else:
            start = j[0]
            end = j[1]
            tag = j[2]
            flag = False
            for k in pred1[i][::-1]:
                if start == k[0]:
                    flag = True
                    if tag == k[-1]:
                        part_match[j[2]] = part_match.get(j[2], 0) + 1
                        print(j, "---", k, " -- Partial Match")
                        pred1[i].remove(k)

                    elif tag != k[-1]:
                        sub[j[2]] = sub.get(j[2], 0) + 1
                        print(j, "---", k, " -- Substitution")
                        pred1[i].remove(k)

            if flag == False:
                print(j, " -- Omission")
                delete[j[2]] = delete.get(j[2], 0) + 1

    if len(pred1[i]) != 0:
        for k in pred1[i]:
            print( k, " -- Hallucination")
            insert[k[-1]] = insert.get(k[-1], 0) + 1
# Out:
# [9, 14, 'LOC'] --- [[9, 14, 'LOC'], [31, 36, 'LOC']]  -- Perfect Match
# [31, 36, 'PERSON'] --- [31, 36, 'LOC']  -- Substitution
# [0, 11, 'PERSON'] --- [[0, 11, 'PERSON']]  -- Perfect Match
# [0, 6, 'LOC'] --- [[0, 6, 'LOC'], [9, 29, 'LOC']]  -- Perfect Match
# [9, 29, 'LOC'] --- [[9, 29, 'LOC']]  -- Perfect Match
# [0, 5, 'LOC'] --- [[0, 5, 'LOC'], [33, 42, 'MISC'], [78, 83, 'LOC']]  -- Perfect Match
# [33, 42, 'MISC'] --- [[33, 42, 'MISC'], [78, 83, 'LOC']]  -- Perfect Match
# [78, 83, 'LOC'] --- [[78, 83, 'LOC']]  -- Perfect Match
# [4, 9, 'LOC'] --- [[4, 9, 'LOC'], [119, 129, 'LOC']]  -- Perfect Match
# [119, 129, 'LOC'] --- [[119, 129, 'LOC']]  -- Perfect Match
# [0, 5, 'LOC'] --- [[0, 5, 'LOC'], [93, 98, 'MISC'], [107, 120, 'PERSON']]  -- Perfect Match
# [93, 98, 'MISC'] --- [[93, 98, 'MISC'], [107, 120, 'PERSON']]  -- Perfect Match
# [107, 120, 'PERSON'] --- [[107, 120, 'PERSON']]  -- Perfect Match
# [205, 212, 'MISC']  -- Omission
# [0, 14, 'PERSON'] --- [[0, 14, 'PERSON']]  -- Perfect Match
# [11, 17, 'MISC'] --- [[11, 17, 'MISC'], [45, 54, 'MISC']]  -- Perfect Match
# [45, 54, 'MISC'] --- [[45, 54, 'MISC']]  -- Perfect Match
# [20, 31, 'MISC'] --- [20, 25, 'MISC']  -- Partial Match
# [54, 64, 'LOC'] --- [[54, 64, 'LOC']]  -- Perfect Match
# [64, 69, 'LOC'] --- [[64, 69, 'LOC'], [154, 159, 'LOC']]  -- Perfect Match
# [154, 159, 'LOC'] --- [[154, 159, 'LOC']]  -- Perfect Match
# [0, 13, 'PERSON'] --- [[0, 13, 'PERSON'], [70, 86, 'PERSON'], [138, 149, 'PERSON']]  -- Perfect Match
# [70, 90, 'PERSON'] --- [70, 86, 'PERSON']  -- Partial Match
# [109, 115, 'MISC']  -- Omission
# [138, 149, 'PERSON'] --- [[138, 149, 'PERSON']]  -- Perfect Match
# [36, 41, 'LOC'] --- [[36, 41, 'LOC']]  -- Perfect Match
# [9, 21, 'PERSON'] --- [[9, 21, 'PERSON'], [138, 141, 'ORG'], [141, 143, 'PERSON']]  -- Perfect Match
# [138, 143, 'PERSON'] --- [138, 141, 'ORG']  -- Substitution
# [141, 143, 'PERSON']  -- Hallucination
# [0, 14, 'PERSON'] --- [[0, 14, 'PERSON'], [25, 30, 'LOC']]  -- Perfect Match
# [25, 30, 'LOC'] --- [[25, 30, 'LOC']]  -- Perfect Match
# [0, 5, 'LOC'] --- [[0, 5, 'LOC']]  -- Perfect Match
# [29, 35, 'MISC']  -- Omission
# [29, 35, 'MISC']  -- Omission
# [0, 5, 'PERSON'] --- [[0, 5, 'PERSON']]  -- Perfect Match
# [0, 5, 'LOC'] --- [[0, 5, 'LOC'], [12, 20, 'PERSON'], [36, 42, 'MISC']]  -- Perfect Match
# [12, 20, 'PERSON'] --- [[12, 20, 'PERSON'], [36, 42, 'MISC']]  -- Perfect Match
# [36, 42, 'MISC'] --- [[36, 42, 'MISC']]  -- Perfect Match
# [4, 11, 'MISC'] --- [[4, 11, 'MISC']]  -- Perfect Match
# [0, 5, 'LOC'] --- [[0, 5, 'LOC']]  -- Perfect Match
# [24, 33, 'MISC']  -- Omission
# [74, 78, 'ORG']  -- Omission
# [6, 9, 'LOC']  -- Omission
# [15, 21, 'LOC']  -- Omission
# [26, 37, 'LOC']  -- Omission
# [46, 55, 'LOC'] --- [[32, 37, 'LOC'], [46, 55, 'LOC']]  -- Perfect Match
# [32, 37, 'LOC']  -- Hallucination
# [0, 11, 'ORG']  -- Omission
# [14, 22, 'PERSON']  -- Omission
# [32, 37, 'LOC'] --- [[6, 22, 'MISC'], [32, 37, 'LOC']]  -- Perfect Match
# [6, 22, 'MISC']  -- Hallucination
# [0, 4, 'LOC'] --- [[0, 4, 'LOC']]  -- Perfect Match
# [0, 5, 'LOC'] --- [[0, 5, 'LOC'], [15, 32, 'PERSON']]  -- Perfect Match
# [15, 32, 'PERSON'] --- [[15, 32, 'PERSON']]  -- Perfect Match
# [37, 45, 'LOC'] --- [[37, 45, 'LOC'], [49, 60, 'LOC']]  -- Perfect Match
# [49, 60, 'LOC'] --- [[49, 60, 'LOC']]  -- Perfect Match
# [0, 8, 'PERSON'] --- [[0, 8, 'PERSON'], [23, 35, 'PERSON'], [153, 160, 'LOC'], [165, 174, 'LOC']]  -- Perfect Match
# [23, 35, 'PERSON'] --- [[23, 35, 'PERSON'], [153, 160, 'LOC'], [165, 174, 'LOC']]  -- Perfect Match
# [153, 160, 'LOC'] --- [[153, 160, 'LOC'], [165, 174, 'LOC']]  -- Perfect Match
# [164, 174, 'LOC']  -- Omission
# [165, 174, 'LOC']  -- Hallucination
# [0, 14, 'PERSON'] --- [[0, 14, 'PERSON'], [42, 47, 'PERSON'], [77, 89, 'PERSON'], [122, 129, 'LOC']]  -- Perfect Match
# [42, 47, 'PERSON'] --- [[42, 47, 'PERSON'], [77, 89, 'PERSON'], [122, 129, 'LOC']]  -- Perfect Match
# [77, 89, 'PERSON'] --- [[77, 89, 'PERSON'], [122, 129, 'LOC']]  -- Perfect Match
# [122, 129, 'LOC'] --- [[122, 129, 'LOC']]  -- Perfect Match
# [0, 8, 'PERSON'] --- [[0, 8, 'PERSON'], [109, 114, 'LOC'], [131, 138, 'LOC']]  -- Perfect Match
# [44, 58, 'MISC']  -- Omission
# [109, 114, 'LOC'] --- [[109, 114, 'LOC'], [131, 138, 'LOC']]  -- Perfect Match
# [131, 138, 'LOC'] --- [[131, 138, 'LOC']]  -- Perfect Match
# [3, 17, 'PERSON'] --- [[3, 17, 'PERSON'], [20, 26, 'LOC']]  -- Perfect Match
# [20, 26, 'LOC'] --- [[20, 26, 'LOC']]  -- Perfect Match
# [3, 25, 'PERSON'] --- [[3, 25, 'PERSON'], [28, 34, 'LOC']]  -- Perfect Match
# [28, 34, 'LOC'] --- [[28, 34, 'LOC']]  -- Perfect Match
# [3, 12, 'PERSON'] --- [[3, 12, 'PERSON'], [15, 19, 'LOC']]  -- Perfect Match
# [15, 19, 'LOC'] --- [[15, 19, 'LOC']]  -- Perfect Match
# [3, 20, 'PERSON'] --- [[3, 20, 'PERSON'], [23, 29, 'LOC']]  -- Perfect Match
# [23, 29, 'LOC'] --- [[23, 29, 'LOC']]  -- Perfect Match
# [3, 18, 'PERSON'] --- [[3, 18, 'PERSON'], [21, 27, 'LOC']]  -- Perfect Match
# [21, 27, 'LOC'] --- [[21, 27, 'LOC']]  -- Perfect Match
# [4, 15, 'PERSON'] --- [[4, 15, 'PERSON'], [18, 22, 'LOC']]  -- Perfect Match
# [18, 22, 'LOC'] --- [[18, 22, 'LOC']]  -- Perfect Match
# [3, 22, 'PERSON'] --- [[3, 22, 'PERSON'], [25, 32, 'LOC']]  -- Perfect Match
# [25, 32, 'LOC'] --- [[25, 32, 'LOC']]  -- Perfect Match
# [3, 15, 'PERSON'] --- [[3, 15, 'PERSON'], [18, 24, 'LOC']]  -- Perfect Match
# [18, 24, 'LOC'] --- [[18, 24, 'LOC']]  -- Perfect Match
# [3, 14, 'PERSON'] --- [[3, 14, 'PERSON'], [17, 24, 'LOC']]  -- Perfect Match
# [17, 24, 'LOC'] --- [[17, 24, 'LOC']]  -- Perfect Match
# [3, 13, 'PERSON'] --- [[3, 13, 'PERSON'], [16, 21, 'LOC']]  -- Perfect Match
# [16, 21, 'LOC'] --- [[16, 21, 'LOC']]  -- Perfect Match
# [3, 16, 'PERSON'] --- [[3, 16, 'PERSON'], [19, 23, 'LOC']]  -- Perfect Match
# [19, 23, 'LOC'] --- [[19, 23, 'LOC']]  -- Perfect Match
# [3, 19, 'PERSON'] --- [[3, 19, 'PERSON'], [22, 26, 'LOC']]  -- Perfect Match
# [22, 26, 'LOC'] --- [[22, 26, 'LOC']]  -- Perfect Match
# [3, 15, 'PERSON'] --- [[3, 15, 'PERSON'], [18, 22, 'LOC']]  -- Perfect Match
# [18, 22, 'LOC'] --- [[18, 22, 'LOC']]  -- Perfect Match
# [3, 17, 'PERSON'] --- [[3, 17, 'PERSON'], [20, 26, 'LOC']]  -- Perfect Match
# [20, 26, 'LOC'] --- [[20, 26, 'LOC']]  -- Perfect Match
# [3, 21, 'PERSON'] --- [[3, 21, 'PERSON'], [24, 30, 'LOC']]  -- Perfect Match
# [24, 30, 'LOC'] --- [[24, 30, 'LOC']]  -- Perfect Match
# [4, 18, 'PERSON'] --- [[4, 18, 'PERSON'], [21, 27, 'LOC']]  -- Perfect Match
# [21, 27, 'LOC'] --- [[21, 27, 'LOC']]  -- Perfect Match
# [9, 18, 'MISC'] --- [[9, 18, 'MISC']]  -- Perfect Match
# [0, 6, 'LOC'] --- [[0, 6, 'LOC'], [9, 29, 'LOC']]  -- Perfect Match
# [9, 29, 'LOC'] --- [[9, 29, 'LOC']]  -- Perfect Match
# [11, 20, 'MISC'] --- [[11, 20, 'MISC']]  -- Perfect Match
# [0, 5, 'LOC'] --- [[0, 5, 'LOC'], [8, 13, 'LOC']]  -- Perfect Match
# [8, 13, 'LOC'] --- [[8, 13, 'LOC']]  -- Perfect Match
# [0, 5, 'LOC'] --- [[0, 5, 'LOC'], [8, 20, 'PERSON'], [35, 48, 'PERSON']]  -- Perfect Match
# [8, 20, 'PERSON'] --- [[8, 20, 'PERSON'], [35, 48, 'PERSON']]  -- Perfect Match
# [35, 48, 'PERSON'] --- [[35, 48, 'PERSON']]  -- Perfect Match
# [0, 5, 'LOC'] --- [[0, 5, 'LOC'], [8, 22, 'PERSON']]  -- Perfect Match
# [8, 22, 'PERSON'] --- [[8, 22, 'PERSON']]  -- Perfect Match
# [0, 5, 'LOC'] --- [[0, 5, 'LOC'], [8, 18, 'LOC']]  -- Perfect Match
# [8, 18, 'LOC'] --- [[8, 18, 'LOC']]  -- Perfect Match
# [10, 23, 'PERSON'] --- [[10, 23, 'PERSON'], [29, 43, 'PERSON']]  -- Perfect Match
# [29, 43, 'PERSON'] --- [[29, 43, 'PERSON']]  -- Perfect Match
# [0, 10, 'LOC'] --- [[0, 10, 'LOC']]  -- Perfect Match
# [0, 5, 'LOC'] --- [[0, 5, 'LOC']]  -- Perfect Match
# [0, 5, 'LOC'] --- [[0, 5, 'LOC']]  -- Perfect Match
# [0, 5, 'LOC'] --- [[0, 5, 'LOC']]  -- Perfect Match
# [10, 18, 'LOC'] --- [[10, 18, 'LOC'], [21, 32, 'LOC']]  -- Perfect Match
# [21, 32, 'LOC'] --- [[21, 32, 'LOC']]  -- Perfect Match
# [18, 21, 'MISC']  -- Omission
# [0, 7, 'LOC'] --- [[0, 7, 'LOC'], [10, 18, 'LOC']]  -- Perfect Match
# [10, 18, 'LOC'] --- [[10, 18, 'LOC']]  -- Perfect Match
# [38, 46, 'LOC']  -- Omission
# [51, 62, 'LOC'] --- [[51, 62, 'LOC']]  -- Perfect Match
# [0, 8, 'LOC'] --- [[0, 8, 'LOC']]  -- Perfect Match
# [0, 11, 'PERSON'] --- [[0, 11, 'PERSON']]  -- Perfect Match
# [0, 12, 'PERSON'] --- [[0, 12, 'PERSON'], [15, 21, 'PERSON']]  -- Perfect Match
# [15, 21, 'PERSON'] --- [[15, 21, 'PERSON']]  -- Perfect Match
# [0, 10, 'PERSON'] --- [[0, 10, 'PERSON'], [13, 21, 'PERSON'], [24, 31, 'PERSON']]  -- Perfect Match
# [13, 21, 'PERSON'] --- [[13, 21, 'PERSON'], [24, 31, 'PERSON']]  -- Perfect Match
# [24, 31, 'PERSON'] --- [[24, 31, 'PERSON']]  -- Perfect Match
# [0, 13, 'PERSON'] --- [[0, 13, 'PERSON'], [14, 16, 'ORG'], [17, 23, 'PERSON'], [26, 28, 'ORG'], [28, 31, 'PERSON']]  -- Perfect Match
# [17, 23, 'PERSON'] --- [[14, 16, 'ORG'], [17, 23, 'PERSON'], [26, 28, 'ORG'], [28, 31, 'PERSON']]  -- Perfect Match
# [26, 31, 'PERSON'] --- [26, 28, 'ORG']  -- Substitution
# [14, 16, 'ORG']  -- Hallucination
# [28, 31, 'PERSON']  -- Hallucination
# [0, 11, 'PERSON'] --- [[0, 11, 'PERSON'], [14, 20, 'PERSON']]  -- Perfect Match
# [14, 20, 'PERSON'] --- [[14, 20, 'PERSON']]  -- Perfect Match
# [0, 13, 'PERSON'] --- [[0, 13, 'PERSON'], [16, 22, 'PERSON']]  -- Perfect Match
# [16, 22, 'PERSON'] --- [[16, 22, 'PERSON']]  -- Perfect Match
# [0, 9, 'PERSON'] --- [[0, 9, 'PERSON'], [12, 17, 'PERSON'], [20, 26, 'PERSON']]  -- Perfect Match
# [12, 17, 'PERSON'] --- [[12, 17, 'PERSON'], [20, 26, 'PERSON']]  -- Perfect Match
# [20, 26, 'PERSON'] --- [[20, 26, 'PERSON']]  -- Perfect Match
# [0, 12, 'PERSON'] --- [0, 2, 'ORG']  -- Substitution
# [16, 22, 'PERSON']  -- Omission
# [25, 31, 'PERSON'] --- [[20, 22, 'PERSON'], [25, 31, 'PERSON']]  -- Perfect Match
# [20, 22, 'PERSON']  -- Hallucination
# [0, 15, 'PERSON'] --- [[0, 15, 'PERSON'], [18, 24, 'PERSON']]  -- Perfect Match
# [18, 24, 'PERSON'] --- [[18, 24, 'PERSON']]  -- Perfect Match
# [0, 13, 'PERSON'] --- [[0, 13, 'PERSON']]  -- Perfect Match
# [0, 11, 'PERSON'] --- [[0, 11, 'PERSON']]  -- Perfect Match
# [10, 15, 'PERSON'] --- [[10, 15, 'PERSON'], [35, 42, 'PERSON']]  -- Perfect Match
# [35, 42, 'PERSON'] --- [[35, 42, 'PERSON']]  -- Perfect Match
# [0, 6, 'PERSON'] --- [0, 6, 'LOC']  -- Substitution
# [26, 33, 'PERSON'] --- [[26, 33, 'PERSON'], [45, 51, 'PERSON']]  -- Perfect Match
# [45, 51, 'PERSON'] --- [[45, 51, 'PERSON']]  -- Perfect Match
# [0, 5, 'PERSON'] --- [0, 5, 'ORG']  -- Substitution
# [0, 11, 'LOC'] --- [[0, 11, 'LOC']]  -- Perfect Match
# [0, 8, 'PERSON']  -- Omission
# [11, 20, 'PERSON'] --- [[1, 8, 'PERSON'], [11, 20, 'PERSON'], [23, 28, 'PERSON']]  -- Perfect Match
# [23, 28, 'PERSON'] --- [[1, 8, 'PERSON'], [23, 28, 'PERSON']]  -- Perfect Match
# [1, 8, 'PERSON']  -- Hallucination
# [0, 11, 'PERSON']  -- Omission
# [14, 23, 'PERSON'] --- [[1, 11, 'PERSON'], [14, 23, 'PERSON'], [26, 31, 'PERSON']]  -- Perfect Match
# [26, 31, 'PERSON'] --- [[1, 11, 'PERSON'], [26, 31, 'PERSON']]  -- Perfect Match
# [1, 11, 'PERSON']  -- Hallucination
# [0, 9, 'PERSON'] --- [[0, 9, 'PERSON'], [12, 22, 'PERSON'], [25, 32, 'PERSON']]  -- Perfect Match
# [12, 22, 'PERSON'] --- [[12, 22, 'PERSON'], [25, 32, 'PERSON']]  -- Perfect Match
# [25, 32, 'PERSON'] --- [[25, 32, 'PERSON']]  -- Perfect Match
# [0, 10, 'PERSON'] --- [[0, 10, 'PERSON'], [19, 25, 'PERSON']]  -- Perfect Match
# [19, 25, 'PERSON'] --- [[19, 25, 'PERSON']]  -- Perfect Match
# [0, 9, 'PERSON'] --- [[0, 9, 'PERSON'], [12, 19, 'PERSON']]  -- Perfect Match
# [12, 19, 'PERSON'] --- [[12, 19, 'PERSON']]  -- Perfect Match
# [0, 8, 'PERSON'] --- [[0, 8, 'PERSON'], [11, 21, 'PERSON'], [24, 35, 'PERSON']]  -- Perfect Match
# [11, 21, 'PERSON'] --- [[11, 21, 'PERSON'], [24, 35, 'PERSON']]  -- Perfect Match
# [24, 35, 'PERSON'] --- [[24, 35, 'PERSON']]  -- Perfect Match
# [0, 9, 'PERSON'] --- [[0, 9, 'PERSON'], [12, 'ORG']]  -- Perfect Match
# [16, 21, 'PERSON']  -- Omission
# [12, 'ORG']  -- Hallucination
# [0, 9, 'PERSON'] --- [[0, 9, 'PERSON'], [16, 22, 'PERSON']]  -- Perfect Match
# [16, 22, 'PERSON'] --- [[16, 22, 'PERSON']]  -- Perfect Match
# [0, 10, 'PERSON'] --- [[0, 10, 'PERSON'], [13, 22, 'PERSON'], [25, 30, 'PERSON']]  -- Perfect Match
# [13, 22, 'PERSON'] --- [[13, 22, 'PERSON'], [25, 30, 'PERSON']]  -- Perfect Match
# [25, 30, 'PERSON'] --- [[25, 30, 'PERSON']]  -- Perfect Match
# [0, 8, 'PERSON'] --- [[0, 8, 'PERSON'], [18, 26, 'PERSON'], [31, 36, 'PERSON']]  -- Perfect Match
# [18, 26, 'PERSON'] --- [[18, 26, 'PERSON'], [31, 36, 'PERSON']]  -- Perfect Match
# [31, 36, 'PERSON'] --- [[31, 36, 'PERSON']]  -- Perfect Match
# [0, 10, 'PERSON'] --- [[0, 10, 'PERSON']]  -- Perfect Match
# [10, 21, 'PERSON'] --- [[10, 21, 'PERSON'], [48, 60, 'PERSON']]  -- Perfect Match
# [48, 60, 'PERSON'] --- [[48, 60, 'PERSON']]  -- Perfect Match
# [24, 39, 'PERSON'] --- [[24, 39, 'PERSON'], [51, 64, 'PERSON']]  -- Perfect Match
# [32, 39, 'PERSON']  -- Omission
# [59, 64, 'PERSON']  -- Omission
# [51, 64, 'PERSON']  -- Hallucination
# [19, 32, 'PERSON'] --- [[19, 32, 'PERSON'], [44, 55, 'PERSON']]  -- Perfect Match
# [44, 55, 'PERSON'] --- [[44, 55, 'PERSON']]  -- Perfect Match
# [0, 10, 'PERSON'] --- [[0, 10, 'PERSON']]  -- Perfect Match
# [9, 17, 'LOC'] --- [[9, 17, 'LOC']]  -- Perfect Match
# [38, 45, 'LOC'] --- [[38, 45, 'LOC']]  -- Perfect Match
# [9, 25, 'MISC'] --- [9, 16, 'MISC']  -- Partial Match
# [17, 20, 'ORG']  -- Hallucination
# [20, 'MISC']  -- Hallucination
# [0, 6, 'LOC'] --- [[0, 6, 'LOC']]  -- Perfect Match
# [13, 35, 'MISC'] --- [13, 20, 'MISC']  -- Partial Match
# [21, 25, 'ORG']  -- Hallucination
# [0, 3, 'MISC']  -- Omission
# [0, 8, 'ORG'] --- [[0, 8, 'ORG'], [11, 17, 'ORG']]  -- Perfect Match
# [11, 17, 'ORG'] --- [[11, 17, 'ORG']]  -- Perfect Match
# [9, 16, 'PERSON']  -- Omission
# [0, 6, 'LOC'] --- [[0, 6, 'LOC']]  -- Perfect Match
# [0, 5, 'MISC'] --- [[0, 5, 'MISC'], [14, 28, 'PERSON'], [108, 117, 'ORG'], [145, 154, 'ORG']]  -- Perfect Match
# [14, 28, 'PERSON'] --- [[14, 28, 'PERSON'], [108, 117, 'ORG'], [145, 154, 'ORG']]  -- Perfect Match
# [69, 73, 'ORG']  -- Omission
# [108, 127, 'ORG'] --- [108, 117, 'ORG']  -- Partial Match
# [145, 154, 'ORG'] --- [[145, 154, 'ORG']]  -- Perfect Match
# [0, 7, 'PERSON'] --- [[0, 7, 'PERSON'], [139, 146, 'ORG'], [172, 181, 'ORG']]  -- Perfect Match
# [48, 52, 'ORG']  -- Omission
# [125, 134, 'ORG']  -- Omission
# [139, 146, 'ORG'] --- [[139, 146, 'ORG'], [172, 181, 'ORG']]  -- Perfect Match
# [172, 181, 'ORG'] --- [[172, 181, 'ORG']]  -- Perfect Match
# [0, 4, 'ORG']  -- Omission
# [48, 57, 'LOC'] --- [48, 57, 'ORG']  -- Substitution
# [86, 93, 'ORG'] --- [[86, 93, 'ORG']]  -- Perfect Match
# [23, 30, 'MISC'] --- [[23, 30, 'MISC'], [82, 91, 'ORG']]  -- Perfect Match
# [82, 91, 'ORG'] --- [[82, 91, 'ORG']]  -- Perfect Match
# [0, 7, 'PERSON'] --- [[0, 7, 'PERSON'], [77, 84, 'ORG'], [120, 127, 'ORG']]  -- Perfect Match
# [25, 30, 'MISC']  -- Omission
# [77, 84, 'MISC'] --- [77, 84, 'ORG']  -- Substitution
# [120, 127, 'ORG'] --- [[120, 127, 'ORG']]  -- Perfect Match
# [9, 14, 'ORG'] --- [[9, 14, 'ORG'], [17, 23, 'PERSON']]  -- Perfect Match
# [17, 23, 'PERSON'] --- [[17, 23, 'PERSON']]  -- Perfect Match
# [0, 6, 'LOC'] --- [[0, 6, 'LOC']]  -- Perfect Match
# [0, 5, 'ORG'] --- [[0, 5, 'ORG'], [8, 15, 'LOC'], [33, 43, 'PERSON']]  -- Perfect Match
# [8, 15, 'LOC'] --- [[8, 15, 'LOC'], [33, 43, 'PERSON']]  -- Perfect Match
# [0, 3, 'PERSON']  -- Omission
# [37, 43, 'PERSON']  -- Omission
# [154, 165, 'ORG']  -- Omission
# [33, 43, 'PERSON']  -- Hallucination
# [0, 6, 'PERSON'] --- [[0, 6, 'PERSON'], [113, 119, 'LOC']]  -- Perfect Match
# [113, 119, 'LOC'] --- [[113, 119, 'LOC']]  -- Perfect Match
# [111, 117, 'LOC']  -- Omission
# [106, 117, 'LOC']  -- Hallucination
# [0, 5, 'ORG'] --- [[0, 5, 'ORG'], [24, 30, 'PERSON']]  -- Perfect Match
# [24, 30, 'PERSON'] --- [[24, 30, 'PERSON']]  -- Perfect Match
# [0, 6, 'PERSON'] --- [[0, 6, 'PERSON'], [123, 136, 'ORG']]  -- Perfect Match
# [26, 35, 'LOC']  -- Omission
# [123, 136, 'ORG'] --- [[123, 136, 'ORG']]  -- Perfect Match
# [13, 23, 'MISC']  -- Omission
# [0, 6, 'LOC'] --- [[0, 6, 'LOC']]  -- Perfect Match
# [24, 34, 'MISC']  -- Omission
# [0, 11, 'ORG'] --- [[0, 11, 'ORG'], [14, 20, 'LOC']]  -- Perfect Match
# [14, 20, 'LOC'] --- [[14, 20, 'LOC']]  -- Perfect Match
# [0, 14, 'ORG'] --- [0, 14, 'PERSON']  -- Substitution
# [17, 22, 'LOC'] --- [[17, 22, 'LOC']]  -- Perfect Match
# [0, 16, 'ORG'] --- [[0, 16, 'ORG'], [19, 25, 'LOC']]  -- Perfect Match
# [19, 25, 'LOC'] --- [[19, 25, 'LOC']]  -- Perfect Match
# [0, 10, 'ORG'] --- [[0, 10, 'ORG'], [13, 19, 'LOC']]  -- Perfect Match
# [13, 19, 'LOC'] --- [[13, 19, 'LOC']]  -- Perfect Match
# [0, 7, 'ORG'] --- [0, 4, 'LOC']  -- Substitution
# [10, 16, 'LOC'] --- [[4, 7, 'ORG'], [10, 16, 'LOC']]  -- Perfect Match
# [4, 7, 'ORG']  -- Hallucination
# [0, 9, 'ORG'] --- [0, 9, 'PERSON']  -- Substitution
# [12, 18, 'LOC'] --- [[12, 18, 'LOC']]  -- Perfect Match
# [0, 18, 'ORG']  -- Omission
# [21, 26, 'LOC'] --- [[5, 18, 'ORG'], [21, 26, 'LOC']]  -- Perfect Match
# [5, 18, 'ORG']  -- Hallucination
# [0, 10, 'ORG'] --- [[0, 10, 'ORG'], [13, 19, 'LOC']]  -- Perfect Match
# [13, 19, 'LOC'] --- [[13, 19, 'LOC']]  -- Perfect Match
# [0, 13, 'ORG'] --- [[0, 13, 'ORG'], [16, 23, 'LOC']]  -- Perfect Match
# [16, 23, 'LOC'] --- [[16, 23, 'LOC']]  -- Perfect Match
# [0, 11, 'ORG'] --- [[0, 11, 'ORG'], [14, 21, 'LOC']]  -- Perfect Match
# [14, 21, 'LOC'] --- [[14, 21, 'LOC']]  -- Perfect Match
# [0, 18, 'ORG'] --- [[0, 18, 'ORG'], [21, 26, 'LOC']]  -- Perfect Match
# [21, 26, 'LOC'] --- [[21, 26, 'LOC']]  -- Perfect Match
# [0, 9, 'ORG'] --- [[0, 9, 'ORG'], [12, 19, 'LOC']]  -- Perfect Match
# [12, 19, 'LOC'] --- [[12, 19, 'LOC']]  -- Perfect Match
# [0, 13, 'ORG'] --- [[0, 13, 'ORG'], [16, 22, 'LOC']]  -- Perfect Match
# [16, 22, 'LOC'] --- [[16, 22, 'LOC']]  -- Perfect Match
# [0, 9, 'ORG'] --- [0, 9, 'LOC']  -- Substitution
# [12, 20, 'LOC'] --- [[12, 20, 'LOC']]  -- Perfect Match
# [0, 12, 'ORG'] --- [0, 12, 'PERSON']  -- Substitution
# [15, 21, 'LOC'] --- [[15, 21, 'LOC']]  -- Perfect Match
# [0, 9, 'ORG'] --- [[0, 9, 'ORG'], [12, 17, 'LOC']]  -- Perfect Match
# [12, 17, 'LOC'] --- [[12, 17, 'LOC']]  -- Perfect Match
# [0, 5, 'ORG'] --- [0, 5, 'LOC']  -- Substitution
# [8, 15, 'LOC'] --- [[8, 15, 'LOC']]  -- Perfect Match
# [0, 16, 'ORG'] --- [[0, 16, 'ORG'], [19, 26, 'LOC']]  -- Perfect Match
# [19, 26, 'LOC'] --- [[19, 26, 'LOC']]  -- Perfect Match
# [0, 11, 'ORG'] --- [[0, 11, 'ORG'], [14, 20, 'LOC']]  -- Perfect Match
# [14, 20, 'LOC'] --- [[14, 20, 'LOC']]  -- Perfect Match
# [0, 10, 'ORG'] --- [0, 4, 'LOC']  -- Substitution
# [13, 19, 'LOC'] --- [[4, 9, 'ORG'], [9, 'LOC'], [13, 19, 'LOC']]  -- Perfect Match
# [4, 9, 'ORG']  -- Hallucination
# [9, 'LOC']  -- Hallucination
# [0, 17, 'ORG'] --- [[0, 17, 'ORG'], [20, 30, 'LOC']]  -- Perfect Match
# [20, 30, 'LOC'] --- [[20, 30, 'LOC']]  -- Perfect Match
# [0, 14, 'ORG'] --- [0, 6, 'PERSON']  -- Substitution
# [17, 22, 'LOC'] --- [[7, 14, 'ORG'], [17, 22, 'LOC']]  -- Perfect Match
# [7, 14, 'ORG']  -- Hallucination
# [0, 7, 'ORG'] --- [[0, 7, 'ORG'], [10, 15, 'LOC']]  -- Perfect Match
# [10, 15, 'LOC'] --- [[10, 15, 'LOC']]  -- Perfect Match
# [0, 13, 'ORG'] --- [[0, 13, 'ORG'], [16, 22, 'LOC']]  -- Perfect Match
# [16, 22, 'LOC'] --- [[16, 22, 'LOC']]  -- Perfect Match
# [0, 11, 'ORG']  -- Omission
# [14, 20, 'PERSON']  -- Omission
# [29, 36, 'PERSON'] --- [[6, 11, 'MISC'], [29, 36, 'PERSON']]  -- Perfect Match
# [6, 11, 'MISC']  -- Hallucination
# [0, 13, 'PERSON'] --- [[0, 13, 'PERSON']]  -- Perfect Match
# [0, 6, 'LOC'] --- [[0, 6, 'LOC']]  -- Perfect Match
# [7, 19, 'PERSON'] --- [[7, 19, 'PERSON'], [30, 39, 'LOC']]  -- Perfect Match
# [30, 39, 'LOC'] --- [[30, 39, 'LOC']]  -- Perfect Match
# [75, 85, 'ORG']  -- Omission
# [89, 99, 'LOC']  -- Omission
# [0, 6, 'PERSON'] --- [[0, 6, 'PERSON'], [145, 159, 'PERSON']]  -- Perfect Match
# [132, 144, 'MISC']  -- Omission
# [145, 159, 'PERSON'] --- [[145, 159, 'PERSON']]  -- Perfect Match
# [0, 12, 'PERSON'] --- [[0, 12, 'PERSON'], [83, 88, 'LOC'], [136, 147, 'PERSON']]  -- Perfect Match
# [83, 88, 'LOC'] --- [[83, 88, 'LOC'], [136, 147, 'PERSON']]  -- Perfect Match
# [136, 147, 'PERSON'] --- [[136, 147, 'PERSON']]  -- Perfect Match
# [4, 13, 'ORG'] --- [4, 11, 'MISC']  -- Substitution
# [78, 86, 'MISC']  -- Omission
# [165, 178, 'PERSON'] --- [[165, 178, 'PERSON'], [225, 235, 'MISC']]  -- Perfect Match
# [225, 235, 'MISC'] --- [[225, 235, 'MISC']]  -- Perfect Match
# [4, 13, 'ORG'] --- [4, 13, 'MISC']  -- Substitution
# [0, 7, 'PERSON']  -- Omission
# [58, 68, 'ORG'] --- [58, 68, 'MISC']  -- Substitution
# [77, 87, 'PERSON'] --- [[77, 87, 'PERSON'], [109, 118, 'LOC'], [191, 200, 'LOC']]  -- Perfect Match
, 172, 'PERSON'], [179, 191, 'PERSON'], [198, 210, 'PERSON'], [217, 229, 'PERSON'], [236, 245, 'PERSON'], [252, 265, 'PERSON'], [272, 284, 'PERSON'], [291, 302, 'PERSON']]  -- Perfect Match
# [159, 172, 'PERSON'] --- [[159, 172, 'PERSON'], [179, 191, 'PERSON'], [198, 210, 'PERSON'], [217, 229, 'PERSON'], [236, 245, 'PERSON'], [252, 265, 'PERSON'], [272, 284, 'PERSON'], [291, 302, 'PERSON']]  -- Perfect Match
# [105, 110, 'PERSON']  -- Omission
# [185, 191, 'PERSON']  -- Omission
# [198, 210, 'PERSON'] --- [[179, 191, 'PERSON'], [198, 210, 'PERSON'], [217, 229, 'PERSON'], [236, 245, 'PERSON'], [252, 265, 'PERSON'], [272, 284, 'PERSON'], [291, 302, 'PERSON']]  -- Perfect Match
# [105, 110, 'PERSON']  -- Omission
# [223, 229, 'PERSON']  -- Omission
# [76, 79, 'PERSON']  -- Omission
# ...
# [32, 44, 'PERSON'] --- [[32, 44, 'PERSON'], [47, 55, 'LOC']]  -- Perfect Match
# [47, 55, 'LOC'] --- [[47, 55, 'LOC']]  -- Perfect Match
# [0, 7, 'PERSON'] --- [[0, 7, 'PERSON'], [10, 15, 'LOC'], [23, 35, 'PERSON'], [38, 46, 'LOC']]  -- Perfect Match
# [10, 15, 'LOC'] --- [[10, 15, 'LOC'], [23, 35, 'PERSON'], [38, 46, 'LOC']]  -- Perfect Match
# [23, 35, 'PERSON'] --- [[23, 35, 'PERSON'], [38, 46, 'LOC']]  -- Perfect Match
# [38, 46, 'LOC'] --- [[38, 46, 'LOC']]  -- Perfect Match
# [0, 16, 'PERSON'] --- [[0, 16, 'PERSON'], [19, 28, 'LOC'], [36, 52, 'PERSON'], [55, 62, 'LOC']]  -- Perfect Match
# [19, 28, 'LOC'] --- [[19, 28, 'LOC'], [36, 52, 'PERSON'], [55, 62, 'LOC']]  -- Perfect Match
# [36, 52, 'PERSON'] --- [[36, 52, 'PERSON'], [55, 62, 'LOC']]  -- Perfect Match
# [55, 62, 'LOC'] --- [[55, 62, 'LOC']]  -- Perfect Match
# [0, 18, 'PERSON'] --- [[0, 18, 'PERSON'], [21, 30, 'LOC'], [38, 60, 'PERSON'], [63, 70, 'LOC']]  -- Perfect Match
# [21, 30, 'LOC'] --- [[21, 30, 'LOC'], [38, 60, 'PERSON'], [63, 70, 'LOC']]  -- Perfect Match
# [38, 60, 'PERSON'] --- [[38, 60, 'PERSON'], [63, 70, 'LOC']]  -- Perfect Match
# [63, 70, 'LOC'] --- [[63, 70, 'LOC']]  -- Perfect Match
# [0, 12, 'PERSON'] --- [[0, 12, 'PERSON'], [15, 24, 'LOC'], [32, 41, 'PERSON'], [44, 49, 'LOC']]  -- Perfect Match
# [15, 24, 'LOC'] --- [[15, 24, 'LOC'], [32, 41, 'PERSON'], [44, 49, 'LOC']]  -- Perfect Match
# [32, 41, 'PERSON'] --- [[32, 41, 'PERSON'], [44, 49, 'LOC']]  -- Perfect Match
# [44, 49, 'LOC'] --- [[44, 49, 'LOC']]  -- Perfect Match
# [29, 41, 'PERSON'] --- [[29, 41, 'PERSON'], [44, 50, 'LOC'], [55, 60, 'PERSON']]  -- Perfect Match
# [44, 50, 'LOC'] --- [[44, 50, 'LOC'], [55, 60, 'PERSON']]  -- Perfect Match
# [55, 60, 'PERSON'] --- [[55, 60, 'PERSON']]  -- Perfect Match
# [58, 72, 'PERSON'] --- [[34, 41, 'PERSON'], [58, 72, 'PERSON'], [75, 82, 'LOC'], [87, 98, 'PERSON'], [101, 106, 'LOC'], [111, 122, 'PERSON'], [125, 130, 'LOC']]  -- Perfect Match
# [75, 82, 'LOC'] --- [[34, 41, 'PERSON'], [75, 82, 'LOC'], [87, 98, 'PERSON'], [101, 106, 'LOC'], [111, 122, 'PERSON'], [125, 130, 'LOC']]  -- Perfect Match
# [87, 98, 'PERSON'] --- [[34, 41, 'PERSON'], [87, 98, 'PERSON'], [101, 106, 'LOC'], [111, 122, 'PERSON'], [125, 130, 'LOC']]  -- Perfect Match
# [101, 106, 'LOC'] --- [[34, 41, 'PERSON'], [101, 106, 'LOC'], [111, 122, 'PERSON'], [125, 130, 'LOC']]  -- Perfect Match
# [111, 122, 'PERSON'] --- [[34, 41, 'PERSON'], [111, 122, 'PERSON'], [125, 130, 'LOC']]  -- Perfect Match
# [101, 106, 'LOC']  -- Omission
# [34, 41, 'PERSON']  -- Hallucination
# [125, 130, 'LOC']  -- Hallucination
# [9, 13, 'MISC'] --- [[9, 13, 'MISC']]  -- Perfect Match
# [30, 51, 'MISC']  -- Omission
# [38, 41, 'MISC']  -- Omission
# [0, 5, 'LOC'] --- [[0, 5, 'LOC']]  -- Perfect Match
# [32, 53, 'MISC']  -- Omission
# [40, 43, 'MISC']  -- Omission
# [71, 87, 'LOC']  -- Omission
# [100, 116, 'ORG'] --- [[100, 116, 'ORG'], [119, 124, 'LOC'], [129, 137, 'ORG'], [140, 145, 'LOC']]  -- Perfect Match
# [119, 124, 'LOC'] --- [[119, 124, 'LOC'], [129, 137, 'ORG'], [140, 145, 'LOC']]  -- Perfect Match
# [129, 137, 'ORG'] --- [[129, 137, 'ORG'], [140, 145, 'LOC']]  -- Perfect Match
# [140, 145, 'LOC'] --- [[140, 145, 'LOC']]  -- Perfect Match
# [0, 10, 'PERSON'] --- [[0, 10, 'PERSON'], [28, 40, 'PERSON']]  -- Perfect Match
# [28, 40, 'PERSON'] --- [[28, 40, 'PERSON']]  -- Perfect Match
# [0, 11, 'ORG']  -- Hallucination
# [0, 3, 'ORG']  -- Omission
# [0, 8, 'LOC'] --- [[0, 8, 'LOC']]  -- Perfect Match
# [13, 28, 'ORG']  -- Omission
# [0, 6, 'ORG']  -- Omission
# [0, 18, 'MISC']  -- Hallucination
# [0, 18, 'MISC']  -- Hallucination
# [0, 8, 'ORG'] --- [[0, 8, 'ORG']]  -- Perfect Match
# [0, 7, 'ORG'] --- [[0, 7, 'ORG']]  -- Perfect Match
# [0, 6, 'ORG'] --- [[0, 6, 'ORG']]  -- Perfect Match
# [0, 8, 'ORG'] --- [[0, 8, 'ORG']]  -- Perfect Match
# [0, 10, 'ORG'] --- [[0, 10, 'ORG']]  -- Perfect Match
# [0, 6, 'ORG'] --- [[0, 6, 'ORG']]  -- Perfect Match
# [0, 8, 'LOC'] --- [0, 17, 'MISC']  -- Substitution
# [0, 7, 'ORG'] --- [[0, 7, 'ORG']]  -- Perfect Match
# [0, 12, 'ORG'] --- [[0, 12, 'ORG']]  -- Perfect Match
# [0, 10, 'ORG'] --- [[0, 10, 'ORG']]  -- Perfect Match
# [0, 10, 'ORG'] --- [[0, 10, 'ORG']]  -- Perfect Match
# [0, 10, 'ORG'] --- [[0, 10, 'ORG']]  -- Perfect Match
# [0, 12, 'ORG'] --- [[0, 12, 'ORG']]  -- Perfect Match
# [0, 9, 'ORG'] --- [[0, 9, 'ORG']]  -- Perfect Match
# [0, 18, 'MISC']  -- Hallucination
# [0, 16, 'MISC'] --- [[0, 16, 'MISC']]  -- Perfect Match
# [0, 7, 'ORG'] --- [[0, 7, 'ORG']]  -- Perfect Match
# [0, 6, 'ORG'] --- [[0, 6, 'ORG']]  -- Perfect Match
# [0, 7, 'ORG'] --- [[0, 7, 'ORG']]  -- Perfect Match
# [0, 8, 'ORG'] --- [[0, 8, 'ORG']]  -- Perfect Match
# [0, 7, 'ORG'] --- [[0, 7, 'ORG']]  -- Perfect Match
# [0, 7, 'ORG'] --- [[0, 7, 'ORG']]  -- Perfect Match
# [0, 7, 'LOC'] --- [0, 16, 'MISC']  -- Substitution
# [0, 8, 'ORG'] --- [[0, 8, 'ORG']]  -- Perfect Match
# [0, 9, 'ORG'] --- [[0, 9, 'ORG']]  -- Perfect Match
# [0, 8, 'ORG'] --- [[0, 8, 'ORG']]  -- Perfect Match
# [0, 11, 'ORG'] --- [[0, 11, 'ORG']]  -- Perfect Match
# [0, 8, 'ORG'] --- [[0, 8, 'ORG']]  -- Perfect Match
# [0, 7, 'ORG'] --- [[0, 7, 'ORG']]  -- Perfect Match
# [0, 7, 'ORG'] --- [[0, 7, 'ORG']]  -- Perfect Match
# [0, 7, 'ORG'] --- [[0, 7, 'ORG'], [11, 18, 'LOC']]  -- Perfect Match
# [11, 18, 'LOC'] --- [[11, 18, 'LOC']]  -- Perfect Match
# [0, 7, 'ORG'] --- [[0, 7, 'ORG'], [11, 13, 'LOC'], [14, 21, 'ORG']]  -- Perfect Match
# [11, 21, 'ORG'] --- [11, 13, 'LOC']  -- Substitution
# [14, 21, 'ORG']  -- Hallucination
# [0, 10, 'ORG'] --- [[0, 10, 'ORG'], [14, 24, 'LOC']]  -- Perfect Match
# [14, 24, 'LOC'] --- [[14, 24, 'LOC']]  -- Perfect Match
# [0, 8, 'ORG'] --- [[0, 8, 'ORG'], [12, 19, 'LOC']]  -- Perfect Match
# [12, 19, 'LOC'] --- [[12, 19, 'LOC']]  -- Perfect Match
# [0, 12, 'ORG'] --- [[0, 12, 'ORG'], [16, 22, 'LOC']]  -- Perfect Match
# [16, 22, 'LOC'] --- [[16, 22, 'LOC']]  -- Perfect Match
# [0, 8, 'ORG'] --- [[0, 8, 'ORG'], [12, 20, 'LOC']]  -- Perfect Match
# [12, 20, 'LOC'] --- [[12, 20, 'LOC']]  -- Perfect Match
# [0, 6, 'ORG'] --- [[0, 6, 'ORG'], [10, 18, 'LOC']]  -- Perfect Match
# [10, 18, 'LOC'] --- [[10, 18, 'LOC']]  -- Perfect Match
# [0, 3, 'ORG']  -- Omission
# [18, 21, 'MISC']  -- Omission
# [0, 8, 'LOC'] --- [[0, 8, 'LOC']]  -- Perfect Match
# [25, 28, 'ORG']  -- Omission
# [32, 35, 'ORG']  -- Omission
# [81, 92, 'ORG']  -- Omission
# [96, 108, 'ORG'] --- [[88, 92, 'ORG'], [96, 108, 'ORG']]  -- Perfect Match
# [88, 92, 'ORG']  -- Hallucination
# [11, 26, 'ORG']  -- Omission
# [0, 6, 'ORG']  -- Omission
# [0, 8, 'ORG'] --- [[0, 8, 'ORG'], [11, 17, 'ORG']]  -- Perfect Match
# [11, 17, 'ORG'] --- [[11, 17, 'ORG']]  -- Perfect Match
# [0, 7, 'ORG'] --- [[0, 7, 'ORG'], [10, 22, 'ORG']]  -- Perfect Match
# [10, 22, 'ORG'] --- [[10, 22, 'ORG']]  -- Perfect Match
# [0, 10, 'ORG'] --- [[0, 10, 'ORG'], [13, 20, 'ORG']]  -- Perfect Match
# [13, 20, 'ORG'] --- [[13, 20, 'ORG']]  -- Perfect Match
# [0, 7, 'ORG'] --- [[0, 7, 'ORG'], [10, 18, 'ORG']]  -- Perfect Match
# [10, 18, 'ORG'] --- [[10, 18, 'ORG']]  -- Perfect Match
# [0, 9, 'ORG'] --- [[0, 9, 'ORG'], [12, 23, 'ORG']]  -- Perfect Match
# [12, 23, 'ORG'] --- [[12, 23, 'ORG']]  -- Perfect Match
# [0, 3, 'ORG'] --- [0, 21, 'MISC']  -- Substitution
# [36, 42, 'ORG']  -- Omission
# [22, 27, 'MISC']  -- Hallucination
# [0, 12, 'LOC'] --- [[0, 12, 'LOC']]  -- Perfect Match
# [19, 37, 'ORG'] --- [[19, 37, 'ORG'], [92, 95, 'MISC'], [141, 160, 'ORG']]  -- Perfect Match
# [141, 160, 'ORG'] --- [[92, 95, 'MISC'], [141, 160, 'ORG']]  -- Perfect Match
# [92, 95, 'MISC']  -- Hallucination
# [0, 14, 'PERSON'] --- [[0, 14, 'PERSON'], [59, 71, 'PERSON'], [125, 130, 'ORG'], [170, 176, 'ORG']]  -- Perfect Match
# [59, 71, 'PERSON'] --- [[59, 71, 'PERSON'], [125, 130, 'ORG'], [170, 176, 'ORG']]  -- Perfect Match
# [125, 130, 'ORG'] --- [[125, 130, 'ORG'], [170, 176, 'ORG']]  -- Perfect Match
# [170, 176, 'ORG'] --- [[170, 176, 'ORG']]  -- Perfect Match
# [0, 11, 'PERSON'] --- [[0, 11, 'PERSON'], [41, 53, 'PERSON'], [107, 116, 'ORG']]  -- Perfect Match
# [41, 53, 'PERSON'] --- [[41, 53, 'PERSON'], [107, 116, 'ORG']]  -- Perfect Match
# [111, 116, 'ORG']  -- Omission
# [107, 116, 'ORG']  -- Hallucination
# [0, 12, 'LOC'] --- [0, 12, 'ORG']  -- Substitution
# [34, 45, 'LOC'] --- [34, 40, 'LOC']  -- Partial Match
# [50, 60, 'LOC'] --- [50, 60, 'ORG']  -- Substitution
# [4, 10, 'ORG'] --- [[4, 10, 'ORG']]  -- Perfect Match
# [0, 12, 'LOC']  -- Omission
# [56, 70, 'ORG']  -- Omission
# [75, 94, 'ORG'] --- [[34, 42, 'MISC'], [75, 94, 'ORG'], [128, 137, 'ORG'], [157, 164, 'ORG']]  -- Perfect Match
# [124, 137, 'ORG']  -- Omission
# [157, 164, 'ORG'] --- [[34, 42, 'MISC'], [128, 137, 'ORG'], [157, 164, 'ORG']]  -- Perfect Match
# [34, 42, 'MISC']  -- Hallucination
# [128, 137, 'ORG']  -- Hallucination
# [12, 24, 'ORG'] --- [[12, 24, 'ORG'], [42, 59, 'ORG'], [89, 92, 'MISC']]  -- Perfect Match
# [42, 59, 'ORG'] --- [[42, 59, 'ORG'], [89, 92, 'MISC']]  -- Perfect Match
# [89, 92, 'MISC']  -- Hallucination
# [4, 9, 'ORG'] --- [[4, 9, 'ORG'], [71, 84, 'PERSON'], [98, 110, 'PERSON'], [126, 141, 'PERSON']]  -- Perfect Match
# [71, 84, 'PERSON'] --- [[71, 84, 'PERSON'], [98, 110, 'PERSON'], [126, 141, 'PERSON']]  -- Perfect Match
# [98, 110, 'PERSON'] --- [[98, 110, 'PERSON'], [126, 141, 'PERSON']]  -- Perfect Match
# [126, 141, 'PERSON'] --- [[126, 141, 'PERSON']]  -- Perfect Match
# [0, 5, 'PERSON'] --- [[0, 5, 'PERSON']]  -- Perfect Match
# [0, 6, 'PERSON'] --- [[0, 6, 'PERSON'], [42, 50, 'ORG']]  -- Perfect Match
# [42, 50, 'PERSON'] --- [42, 50, 'ORG']  -- Substitution
# [0, 6, 'PERSON'] --- [[0, 6, 'PERSON']]  -- Perfect Match
# [15, 26, 'PERSON'] --- [[15, 26, 'PERSON'], [56, 70, 'ORG'], [160, 175, 'PERSON']]  -- Perfect Match
# [56, 70, 'ORG'] --- [[56, 70, 'ORG'], [160, 175, 'PERSON']]  -- Perfect Match
# [82, 85, 'ORG']  -- Omission
# [160, 175, 'PERSON'] --- [[160, 175, 'PERSON']]  -- Perfect Match
# [39, 51, 'LOC'] --- [39, 51, 'ORG']  -- Substitution
# [55, 67, 'PERSON'] --- [[55, 67, 'PERSON'], [77, 79, 'PERSON']]  -- Perfect Match
# [75, 80, 'PERSON']  -- Omission
# [77, 79, 'PERSON']  -- Hallucination
# [0, 6, 'ORG'] --- [[0, 6, 'ORG'], [19, 28, 'PERSON']]  -- Perfect Match
# [19, 28, 'PERSON'] --- [[19, 28, 'PERSON']]  -- Perfect Match
# [0, 13, 'PERSON'] --- [[0, 13, 'PERSON'], [30, 33, 'MISC']]  -- Perfect Match
# [30, 33, 'MISC']  -- Hallucination
# [0, 3, 'ORG'] --- [0, 3, 'MISC']  -- Substitution
# [0, 8, 'LOC'] --- [[0, 8, 'LOC']]  -- Perfect Match
# [13, 21, 'ORG']  -- Omission
# [0, 22, 'ORG'] --- [[0, 22, 'ORG']]  -- Perfect Match
# [0, 18, 'MISC']  -- Hallucination
# [0, 8, 'LOC'] --- [0, 17, 'MISC']  -- Substitution
# [0, 5, 'ORG'] --- [[0, 5, 'ORG']]  -- Perfect Match
# [0, 8, 'ORG'] --- [[0, 8, 'ORG']]  -- Perfect Match
# [0, 7, 'ORG'] --- [[0, 7, 'ORG']]  -- Perfect Match
# [0, 10, 'ORG'] --- [0, 10, 'LOC']  -- Substitution
# [0, 12, 'ORG'] --- [[0, 12, 'ORG']]  -- Perfect Match
# [0, 6, 'ORG'] --- [[0, 6, 'ORG']]  -- Perfect Match
# [0, 10, 'ORG'] --- [[0, 10, 'ORG']]  -- Perfect Match
# [0, 16, 'MISC']  -- Hallucination
# [0, 7, 'ORG'] --- [[0, 7, 'ORG']]  -- Perfect Match
# [0, 7, 'ORG'] --- [[0, 7, 'ORG']]  -- Perfect Match
# [0, 9, 'ORG'] --- [[0, 9, 'ORG']]  -- Perfect Match
# [0, 7, 'ORG'] --- [[0, 7, 'ORG']]  -- Perfect Match
# [0, 9, 'ORG'] --- [[0, 9, 'ORG']]  -- Perfect Match
# [0, 9, 'ORG'] --- [[0, 9, 'ORG']]  -- Perfect Match
# [0, 7, 'ORG'] --- [[0, 7, 'ORG']]  -- Perfect Match
# [0, 7, 'ORG'] --- [[0, 7, 'ORG']]  -- Perfect Match
# [0, 18, 'MISC']  -- Hallucination
# [0, 7, 'MISC']  -- Hallucination
# [0, 7, 'ORG'] --- [[0, 7, 'ORG']]  -- Perfect Match
# [0, 4, 'ORG'] --- [[0, 4, 'ORG']]  -- Perfect Match
# [0, 9, 'ORG'] --- [[0, 9, 'ORG']]  -- Perfect Match
# [0, 6, 'ORG'] --- [[0, 6, 'ORG']]  -- Perfect Match
# [0, 6, 'ORG'] --- [[0, 6, 'ORG']]  -- Perfect Match
# [0, 11, 'ORG'] --- [[0, 11, 'ORG']]  -- Perfect Match
# [0, 9, 'ORG'] --- [[0, 9, 'ORG']]  -- Perfect Match
# [0, 7, 'LOC'] --- [0, 16, 'MISC']  -- Substitution
# [0, 7, 'ORG'] --- [[0, 7, 'ORG']]  -- Perfect Match
# [0, 9, 'ORG'] --- [[0, 9, 'ORG']]  -- Perfect Match
# [0, 8, 'ORG'] --- [[0, 8, 'ORG']]  -- Perfect Match
# [0, 11, 'ORG'] --- [[0, 11, 'ORG']]  -- Perfect Match
# [0, 12, 'ORG'] --- [[0, 12, 'ORG']]  -- Perfect Match
# [0, 10, 'ORG'] --- [[0, 10, 'ORG']]  -- Perfect Match
# [0, 7, 'ORG'] --- [[0, 7, 'ORG']]  -- Perfect Match
# [0, 10, 'ORG'] --- [[0, 10, 'ORG'], [14, 20, 'LOC']]  -- Perfect Match
# [14, 20, 'LOC'] --- [[14, 20, 'LOC']]  -- Perfect Match
# [0, 9, 'ORG'] --- [[0, 9, 'ORG'], [13, 20, 'LOC']]  -- Perfect Match
# [13, 20, 'LOC'] --- [[13, 20, 'LOC']]  -- Perfect Match
# [0, 8, 'ORG'] --- [[0, 8, 'ORG'], [12, 17, 'LOC']]  -- Perfect Match
# [12, 17, 'LOC'] --- [[12, 17, 'LOC']]  -- Perfect Match
# [0, 7, 'ORG'] --- [[0, 7, 'ORG'], [11, 21, 'LOC']]  -- Perfect Match
# [11, 21, 'LOC'] --- [[11, 21, 'LOC']]  -- Perfect Match
# [0, 9, 'ORG'] --- [[0, 9, 'ORG'], [13, 24, 'LOC']]  -- Perfect Match
# [13, 24, 'LOC'] --- [[13, 24, 'LOC']]  -- Perfect Match
# [0, 9, 'ORG'] --- [[0, 9, 'ORG'], [13, 17, 'LOC']]  -- Perfect Match
# [13, 17, 'LOC'] --- [[13, 17, 'LOC']]  -- Perfect Match
# [0, 9, 'ORG'] --- [[0, 9, 'ORG'], [13, 21, 'LOC']]  -- Perfect Match
# [13, 21, 'LOC'] --- [[13, 21, 'LOC']]  -- Perfect Match
# [0, 7, 'ORG'] --- [[0, 7, 'ORG']]  -- Perfect Match
# [11, 23, 'LOC']  -- Omission
# [0, 7, 'ORG'] --- [0, 7, 'PERSON']  -- Substitution
# [2, 4, 'LOC']  -- Omission
# [14, 20, 'LOC'] --- [14, 20, 'ORG']  -- Substitution
# [11, 13, 'LOC']  -- Hallucination
# [0, 3, 'ORG']  -- Omission
# [4, 12, 'MISC']  -- Hallucination
# [0, 8, 'LOC'] --- [[0, 8, 'LOC']]  -- Perfect Match
# [0, 24, 'ORG'] --- [0, 24, 'MISC']  -- Substitution
# [0, 8, 'MISC'] --- [[0, 8, 'MISC']]  -- Perfect Match
# [0, 16, 'MISC']  -- Hallucination
# [0, 11, 'ORG'] --- [[0, 11, 'ORG']]  -- Perfect Match
# [0, 7, 'ORG'] --- [[0, 7, 'ORG']]  -- Perfect Match
# [0, 12, 'ORG'] --- [[0, 12, 'ORG']]  -- Perfect Match
# [0, 5, 'ORG'] --- [[0, 5, 'ORG']]  -- Perfect Match
# [0, 7, 'ORG'] --- [[0, 7, 'ORG']]  -- Perfect Match
# [0, 16, 'MISC']  -- Hallucination
# [9, 11, 'ORG']  -- Omission

# %%
perfect = []
part = []
substituted = []
hallucinated = []
omitted = []

for i in list(label_list):
    try:
        num = labels4[i]
        perfect.append((perf_match[i]/num)*100)
        part.append((part_match[i]/num)*100)
        substituted.append((sub[i]/num)*100)
        hallucinated.append(insert[i])
        omitted.append((delete[i]/num)*100)

    except:
        perfect.append(0)
        part.append(0)
        substituted.append(0)
        hallucinated.append(0)
        omitted.append(0)

lists = [perfect, part, substituted, hallucinated, omitted]
list_names = ["Perfect Match Percentage", "Partial Match Percentage", "Percentage of times the Tag was Misclassified as some other Tag", "Number of times, the Tag was wrongly Inserted", "Percentage of times the Tag was not Detected"]

for i, data in enumerate(lists):
    plt.figure(figsize=(10, 6))
    plt.bar(label_list, data, color='maroon')
    plt.xlabel('Labels')
    plt.ylabel('Percentage')
    plt.title(list_names[i])
    plt.xticks(rotation=90)
    plt.tight_layout()
    plt.show()

# %%
import pandas as pd

data = {
    'Tag': list(label_list),
    'Perfect (%)': perfect,
    'Part (%)': part,
    'Substituted (%)': substituted,
    'Hallucinated': hallucinated,
    'Omitted (%)': omitted
}

df = pd.DataFrame(data)
df
# Out:
#       Tag  Perfect (%)   Part (%)  Substituted (%)  Hallucinated  Omitted (%)
# 0       O     0.000000   0.000000         0.000000             0     0.000000
# 1  PERSON    85.683297   1.301518         1.735358            28    11.279826
# 2     LOC    80.622837   1.384083         6.920415            17    11.072664
# 3    MISC    32.352941  10.294118         4.411765            22    52.941176
# 4     ORG    72.872340   0.531915         9.574468            17    17.021277

# %%
import pandas as pd

data = {
    'Tag': ['O', 'PERSON', 'LOC', 'MISC', 'ORG'],
    'Perfect (%)': [0.000000, 85.683297, 80.622837, 32.352941, 72.872340],
    'Part (%)': [0.000000, 1.301518, 1.384083, 10.294118, 0.531915],
    'Substituted (%)': [0.000000, 1.735358, 6.920415, 4.411765, 9.574468],
    'Hallucinated': [0, 28, 17, 22, 17],
    'Omitted (%)': [0.000000, 11.279826, 11.072664, 52.941176, 17.021277]
}


df = pd.DataFrame(data)

avg_row = df.iloc[1:].mean()
avg_row['Tag'] = 'Average'

df = df.append(avg_row, ignore_index=True)

df
# Out:
# /var/folders/yl/5879yj014q11kbqcnjh_rd0m0000gn/T/ipykernel_7275/1532506185.py:15: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   avg_row = df.iloc[1:].mean()
# /var/folders/yl/5879yj014q11kbqcnjh_rd0m0000gn/T/ipykernel_7275/1532506185.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(avg_row, ignore_index=True)
#        Tag  Perfect (%)   Part (%)  Substituted (%)  Hallucinated  Omitted (%)
# 0        O     0.000000   0.000000         0.000000           0.0     0.000000
# 1   PERSON    85.683297   1.301518         1.735358          28.0    11.279826
# 2      LOC    80.622837   1.384083         6.920415          17.0    11.072664
# 3     MISC    32.352941  10.294118         4.411765          22.0    52.941176
# 4      ORG    72.872340   0.531915         9.574468          17.0    17.021277
# 5  Average    67.882854   3.377908         5.660501          21.0    23.078736
